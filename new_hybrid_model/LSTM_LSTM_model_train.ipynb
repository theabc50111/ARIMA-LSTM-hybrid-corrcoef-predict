# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math
import os
from pathlib import Path
import random
from tqdm import tqdm
from itertools import combinations
from sklearn.metrics import mean_squared_error, mean_absolute_error
from pmdarima.arima import ARIMA, auto_arima
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy import stats as st
from sklearn.linear_model import LinearRegression
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l1_l2
from tensorflow.data import Dataset
import warnings
warnings.simplefilter("ignore")

# %load_ext pycodestyle_magic
# %pycodestyle_on --ignore E501
# Out:
# time: 1.86 s (started: 2022-09-03 14:45:44 +00:00)

# %% [markdown]
# # Prepare data

# %%
data_implement = "tw50"  # SP500_20082017|tw50|sp500_19972007|tetuan_power
dataset_path = Path("./dataset/")
if data_implement == "sp500_20082017":
    file_name = Path("../../../stock08_price.csv")
    train_set =['CELG', 'PXD', 'WAT', 'LH', 'AMGN', 'AOS', 'EFX', 'CRM', 'NEM', 'JNPR', 'LB', 'CTAS', 'MAT', 'MDLZ', 'VLO', 'APH', 'ADM', 'MLM', 'BK', 'NOV', 'BDX', 'RRC', 'IVZ', 'ED', 'SBUX', 'GRMN', 'CI', 'ZION', 'COO', 'TIF', 'RHT', 'FDX', 'LLL', 'GLW', 'GPN', 'IPGP', 'GPC', 'HPQ', 'ADI', 'AMG', 'MTB', 'YUM', 'SYK', 'KMX', 'AME', 'AAP', 'DAL', 'A', 'MON', 'BRK', 'BMY', 'KMB', 'JPM', 'CCI', 'AET', 'DLTR', 'MGM', 'FL', 'HD', 'CLX', 'OKE', 'UPS', 'WMB', 'IFF', 'CMS', 'ARNC', 'VIAB', 'MMC', 'REG', 'ES', 'ITW', 'NDAQ', 'AIZ', 'VRTX', 'CTL', 'QCOM', 'MSI', 'NKTR', 'AMAT', 'BWA', 'ESRX', 'TXT', 'EXR', 'VNO', 'BBT', 'WDC', 'UAL', 'PVH', 'NOC', 'PCAR', 'NSC', 'UAA', 'FFIV', 'PHM', 'LUV', 'HUM', 'SPG', 'SJM', 'ABT', 'CMG', 'ALK', 'ULTA', 'TMK', 'TAP', 'SCG', 'CAT', 'TMO', 'AES', 'MRK', 'RMD', 'MKC', 'WU', 'ACN', 'HIG', 'TEL', 'DE', 'ATVI', 'O', 'UNM', 'VMC', 'ETFC', 'CMA', 'NRG', 'RHI', 'RE', 'FMC', 'MU', 'CB', 'LNT', 'GE', 'CBS', 'ALGN', 'SNA', 'LLY', 'LEN', 'MAA', 'OMC', 'F', 'APA', 'CDNS', 'SLG', 'HP', 'XLNX', 'SHW', 'AFL', 'STT', 'PAYX', 'AIG', 'FOX', 'MA']
elif data_implement == "tw50":
    file_name = Path("tw50_hold_20082018_adj_close_pre.csv")
    train_set = ['萬海_adj_close', '豐泰_adj_close', '友達_adj_close', '欣興_adj_close', '台塑化_adj_close', '和泰車_adj_close', '元大金_adj_close', '南電_adj_close', '台塑_adj_close', '統一超_adj_close', '台泥_adj_close', '瑞昱_adj_close', '彰銀_adj_close', '富邦金_adj_close', '研華_adj_close', '中鋼_adj_close', '鴻海_adj_close', '台新金_adj_close', '遠傳_adj_close', '南亞_adj_close', '台達電_adj_close', '台灣大_adj_close', '台化_adj_close', '聯詠_adj_close', '廣達_adj_close', '聯發科_adj_close', '台積電_adj_close', '統一_adj_close', '中信金_adj_close', '長榮_adj_close']
elif data_implement == "sp500_19972007":
    file_name = Path("sp500_hold_19972007_adj_close_pre.csv")
    train_set = ['PXD', 'WAT', 'LH', 'AMGN', 'AOS', 'EFX', 'NEM', 'CTAS', 'MAT', 'VLO', 'APH', 'ADM', 'MLM', 'BK', 'NOV', 'BDX', 'RRC', 'IVZ', 'ED', 'SBUX', 'CI', 'ZION', 'COO', 'FDX', 'GLW', 'GPC', 'HPQ', 'ADI', 'AMG', 'MTB', 'YUM', 'SYK', 'KMX', 'AME', 'BMY', 'KMB', 'JPM', 'AET', 'DLTR', 'MGM', 'FL', 'HD', 'CLX', 'OKE', 'WMB', 'IFF', 'CMS', 'MMC', 'REG', 'ES', 'ITW', 'VRTX', 'QCOM', 'MSI', 'NKTR', 'AMAT', 'BWA', 'ESRX', 'TXT', 'VNO', 'WDC', 'PVH', 'NOC', 'PCAR', 'NSC', 'PHM', 'LUV', 'HUM', 'SPG', 'SJM', 'ABT', 'ALK', 'TAP', 'CAT', 'TMO', 'AES', 'MRK', 'RMD', 'MKC', 'HIG', 'DE', 'ATVI', 'O', 'UNM', 'VMC', 'CMA', 'RHI', 'RE', 'FMC', 'MU', 'CB', 'LNT', 'GE', 'SNA', 'LLY', 'LEN', 'MAA', 'OMC', 'F', 'APA', 'CDNS', 'SLG', 'HP', 'SHW', 'AFL', 'STT', 'PAYX', 'AIG']
elif data_implement == "tetuan_power":
    file_name = Path("Tetuan City power consumption_pre.csv")
    train_set = ["Temperature", "Humidity", "Wind Speed", "general diffuse flows", "diffuse flows", "Zone 1 Power Consumption", "Zone 2  Power Consumption", "Zone 3  Power Consumption"]

dataset_df = pd.read_csv(dataset_path/file_name)
all_set = list(dataset_df.columns.values[1:]) # all data
print(f"len(train_set): {len(train_set)}, len(all_set): {len(all_set)}")
      
train_info = {"paper_eva_1": {"items": ['PRGO', 'MRO', 'ADP', 'HCP', 'FITB', 'PEG', 'SYMC', 'EOG', 'MDT', 'NI'], "file_name": "paper_eva_1_res"}, 
              "paper_eva_2": {"items": ['STI', 'COP', 'MCD', 'AON', 'JBHT', 'DISH', 'GS', 'LRCX', 'CTXS', 'LEG'], "file_name": "paper_eva_2_res"},
              "paper_eva_3": {"items": ['TJX', 'EMN', 'JCI', 'C', 'BIIB', 'HOG', 'PX', 'PH', 'XEC', 'JEC'], "file_name": "paper_eva_3_res"},
              "paper_eva_4": {"items": ['ROP', 'AZO', 'URI', 'TROW', 'CMCSA', 'SLB', 'VZ', 'MAC', 'ADS', 'MCK'], "file_name": "paper_eva_4_res"},
              "paper_eva_5": {"items": ['RL', 'CVX', 'SRE', 'PFE', 'PCG', 'UTX', 'NTRS', 'INCY', 'COP', 'HRL'], "file_name": "paper_eva_5_res"},
              "tw50": {"items":train_set, "file_name": "tw50_20082017_res"},
              "sp500_19972007": {"items":train_set, "file_name": "sp500_19972007_res"},
              "sp500_20082017": {"items":train_set, "file_name": "sp500_20082017_res"},
              "tetuan_power": {"items": train_set, "file_name":  f"tetuan_power_res"},
             }
             

items_implement = train_info[data_implement]['items']
output_file_name = train_info[data_implement]['file_name']

dataset_df = dataset_df.set_index('Date')
# display(dataset_df)
# Out:
# len(train_set): 30, len(all_set): 40
# time: 11.4 ms (started: 2022-09-03 14:45:46 +00:00)

# %%
def gen_data_corr(items: list, corr_ind: list) -> "pd.DataFrame":
    tmp_corr = dataset_df[items[0]].rolling(window=100).corr(dataset_df[items[1]])
    tmp_corr = tmp_corr.iloc[corr_ind].values
    data_df = pd.DataFrame(tmp_corr.reshape(-1, 24))
    ind = [f"{items[0]} & {items[1]}_{i}" for i in range(0, 100, 20)]
    data_df.index = ind
    return data_df


def gen_train_data(items: list, corr_ind: list, save_file: bool = False)-> "four pd.DataFrame":
    train_df = pd.DataFrame()
    dev_df = pd.DataFrame()
    test1_df = pd.DataFrame()
    test2_df = pd.DataFrame()

    for pair in tqdm(combinations(items, 2)):
        data_df = gen_data_corr([pair[0], pair[1]], corr_ind=corr_ind)
        data_split = {'train': [0, 21], 'dev': [1, 22], 'test1': [2, 23], 'test2': [3, 24]}
        train_df = pd.concat([train_df, data_df.iloc[:, 0:21]])
        dev_df = pd.concat([dev_df, data_df.iloc[:, 1:22]])
        test1_df = pd.concat([test1_df, data_df.iloc[:, 2:23]])
        test2_df = pd.concat([test2_df, data_df.iloc[:, 3:24]])

    if save_file:
        Path('./dataset/before_arima/').mkdir(parents=True, exist_ok=True)
        train_df.to_csv(f"./dataset/before_arima/{output_file_name}_train.csv")
        dev_df.to_csv(f"./dataset/before_arima/{output_file_name}_dev.csv")
        test1_df.to_csv(f"./dataset/before_arima/{output_file_name}_test1.csv")
        test2_df.to_csv(f"./dataset/before_arima/{output_file_name}_test2.csv")

    return train_df, dev_df, test1_df, test2_df 


corr_ind = list(range(99, 2400, 100))  + list(range(99+20, 2500, 100)) + list(range(99+40, 2500, 100)) + list(range(99+60, 2500, 100)) + list(range(99+80, 2500, 100))
corr_datasets = gen_train_data(items_implement, corr_ind, save_file = True)
# Out:
# 435it [00:00, 653.25it/s]
# time: 799 ms (started: 2022-09-03 14:45:48 +00:00)

# %% [markdown]
# # LSTM model for first stage prediciton

# %%
model_dir = './models/first_stage_lstm_weight'
log_dir = './models/first_stage_lstm_train_logs'
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
model_log = keras.callbacks.TensorBoard(log_dir=log_dir)
model_earlystop = tf.keras.callbacks.EarlyStopping(patience=50, monitor="val_loss")
save_model = keras.callbacks.ModelCheckpoint(Path(model_dir)/"epoch_{epoch}_{val_loss:.5f}.h5",
                                             monitor='val_loss', verbose=1, mode='min', save_best_only=True)
callbacks_list = [model_log, model_earlystop, save_model]
inputs = Input(shape=(20, 1))
lstm_1 = LSTM(units=20, kernel_regularizer=l1_l2(0.0, 0.0), bias_regularizer=l1_l2(0.0, 0.0))(inputs)
outputs = Dense(units=21, activation="relu")(lstm_1)
first_stage_lstm_model = keras.Model(inputs, outputs, name="first_stage_lstm")
first_stage_lstm_model.summary()
first_stage_lstm_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae'])
train_history = first_stage_lstm_model.fit(x=corr_datasets[0], y=corr_datasets[0], validation_data=(corr_datasets[1], corr_datasets[1]), epochs=500, batch_size=64, shuffle=True, callbacks=callbacks_list, verbose=1)
# Out:
# Model: "first_stage_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 21, 1)]           0
#
#  lstm_8 (LSTM)               (None, 21)                1932
#
#  dense_8 (Dense)             (None, 21)                462
#
# =================================================================
# Total params: 2,394
# Trainable params: 2,394
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.2451 - mse: 0.2451 - mae: 0.4181
# Epoch 1: val_loss improved from inf to 0.23688, saving model to models/first_stage_lstm_weight/epoch_1_0.23688.h5
# 218/218 [==============================] - 2s 6ms/step - loss: 0.2446 - mse: 0.2446 - mae: 0.4175 - val_loss: 0.2369 - val_mse: 0.2369 - val_mae: 0.4077
# Epoch 2/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.2128 - mse: 0.2128 - mae: 0.3820
# Epoch 2: val_loss improved from 0.23688 to 0.22775, saving model to models/first_stage_lstm_weight/epoch_2_0.22775.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.2125 - mse: 0.2125 - mae: 0.3817 - val_loss: 0.2278 - val_mse: 0.2278 - val_mae: 0.3954
# Epoch 3/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1923 - mse: 0.1923 - mae: 0.3591
# Epoch 3: val_loss improved from 0.22775 to 0.21272, saving model to models/first_stage_lstm_weight/epoch_3_0.21272.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1923 - mse: 0.1923 - mae: 0.3591 - val_loss: 0.2127 - val_mse: 0.2127 - val_mae: 0.3789
# Epoch 4/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1823 - mse: 0.1823 - mae: 0.3472
# Epoch 4: val_loss improved from 0.21272 to 0.20878, saving model to models/first_stage_lstm_weight/epoch_4_0.20878.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1822 - mse: 0.1822 - mae: 0.3471 - val_loss: 0.2088 - val_mse: 0.2088 - val_mae: 0.3752
# Epoch 5/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1787 - mse: 0.1787 - mae: 0.3418
# Epoch 5: val_loss improved from 0.20878 to 0.20529, saving model to models/first_stage_lstm_weight/epoch_5_0.20529.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1789 - mse: 0.1789 - mae: 0.3420 - val_loss: 0.2053 - val_mse: 0.2053 - val_mae: 0.3710
# Epoch 6/3000
# 211/218 [============================>.] - ETA: 0s - loss: 0.1766 - mse: 0.1766 - mae: 0.3385
# Epoch 6: val_loss improved from 0.20529 to 0.20494, saving model to models/first_stage_lstm_weight/epoch_6_0.20494.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1765 - mse: 0.1765 - mae: 0.3385 - val_loss: 0.2049 - val_mse: 0.2049 - val_mae: 0.3685
# Epoch 7/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.1750 - mse: 0.1750 - mae: 0.3361
# Epoch 7: val_loss improved from 0.20494 to 0.20222, saving model to models/first_stage_lstm_weight/epoch_7_0.20222.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1747 - mse: 0.1747 - mae: 0.3357 - val_loss: 0.2022 - val_mse: 0.2022 - val_mae: 0.3663
# Epoch 8/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1718 - mse: 0.1718 - mae: 0.3320
# Epoch 8: val_loss improved from 0.20222 to 0.19398, saving model to models/first_stage_lstm_weight/epoch_8_0.19398.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1718 - mse: 0.1718 - mae: 0.3320 - val_loss: 0.1940 - val_mse: 0.1940 - val_mae: 0.3580
# Epoch 9/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1634 - mse: 0.1634 - mae: 0.3227
# Epoch 9: val_loss improved from 0.19398 to 0.18662, saving model to models/first_stage_lstm_weight/epoch_9_0.18662.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1634 - mse: 0.1634 - mae: 0.3227 - val_loss: 0.1866 - val_mse: 0.1866 - val_mae: 0.3494
# Epoch 10/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1587 - mse: 0.1587 - mae: 0.3171
# Epoch 10: val_loss improved from 0.18662 to 0.18451, saving model to models/first_stage_lstm_weight/epoch_10_0.18451.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1587 - mse: 0.1587 - mae: 0.3171 - val_loss: 0.1845 - val_mse: 0.1845 - val_mae: 0.3493
# Epoch 11/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1576 - mse: 0.1576 - mae: 0.3155
# Epoch 11: val_loss improved from 0.18451 to 0.18348, saving model to models/first_stage_lstm_weight/epoch_11_0.18348.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1576 - mse: 0.1576 - mae: 0.3156 - val_loss: 0.1835 - val_mse: 0.1835 - val_mae: 0.3466
# Epoch 12/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.1561 - mse: 0.1561 - mae: 0.3133
# Epoch 12: val_loss did not improve from 0.18348
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1564 - mse: 0.1564 - mae: 0.3137 - val_loss: 0.1845 - val_mse: 0.1845 - val_mae: 0.3493
# Epoch 13/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1554 - mse: 0.1554 - mae: 0.3123
# Epoch 13: val_loss improved from 0.18348 to 0.18138, saving model to models/first_stage_lstm_weight/epoch_13_0.18138.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1553 - mse: 0.1553 - mae: 0.3122 - val_loss: 0.1814 - val_mse: 0.1814 - val_mae: 0.3440
# Epoch 14/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1537 - mse: 0.1537 - mae: 0.3098
# Epoch 14: val_loss improved from 0.18138 to 0.17955, saving model to models/first_stage_lstm_weight/epoch_14_0.17955.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1537 - mse: 0.1537 - mae: 0.3098 - val_loss: 0.1795 - val_mse: 0.1795 - val_mae: 0.3385
# Epoch 15/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1525 - mse: 0.1525 - mae: 0.3082
# Epoch 15: val_loss did not improve from 0.17955
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1525 - mse: 0.1525 - mae: 0.3082 - val_loss: 0.1819 - val_mse: 0.1819 - val_mae: 0.3462
# Epoch 16/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1511 - mse: 0.1511 - mae: 0.3064
# Epoch 16: val_loss improved from 0.17955 to 0.17749, saving model to models/first_stage_lstm_weight/epoch_16_0.17749.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1512 - mse: 0.1512 - mae: 0.3066 - val_loss: 0.1775 - val_mse: 0.1775 - val_mae: 0.3388
# Epoch 17/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1497 - mse: 0.1497 - mae: 0.3048
# Epoch 17: val_loss improved from 0.17749 to 0.17618, saving model to models/first_stage_lstm_weight/epoch_17_0.17618.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1499 - mse: 0.1499 - mae: 0.3050 - val_loss: 0.1762 - val_mse: 0.1762 - val_mae: 0.3368
# Epoch 18/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1484 - mse: 0.1484 - mae: 0.3032
# Epoch 18: val_loss improved from 0.17618 to 0.17448, saving model to models/first_stage_lstm_weight/epoch_18_0.17448.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1484 - mse: 0.1484 - mae: 0.3032 - val_loss: 0.1745 - val_mse: 0.1745 - val_mae: 0.3342
# Epoch 19/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1468 - mse: 0.1468 - mae: 0.3012
# Epoch 19: val_loss improved from 0.17448 to 0.17337, saving model to models/first_stage_lstm_weight/epoch_19_0.17337.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1468 - mse: 0.1468 - mae: 0.3012 - val_loss: 0.1734 - val_mse: 0.1734 - val_mae: 0.3341
# Epoch 20/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1453 - mse: 0.1453 - mae: 0.2993
# Epoch 20: val_loss improved from 0.17337 to 0.17160, saving model to models/first_stage_lstm_weight/epoch_20_0.17160.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1453 - mse: 0.1453 - mae: 0.2992 - val_loss: 0.1716 - val_mse: 0.1716 - val_mae: 0.3304
# Epoch 21/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1435 - mse: 0.1435 - mae: 0.2967
# Epoch 21: val_loss improved from 0.17160 to 0.17128, saving model to models/first_stage_lstm_weight/epoch_21_0.17128.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1437 - mse: 0.1437 - mae: 0.2969 - val_loss: 0.1713 - val_mse: 0.1713 - val_mae: 0.3312
# Epoch 22/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1426 - mse: 0.1426 - mae: 0.2955
# Epoch 22: val_loss improved from 0.17128 to 0.17005, saving model to models/first_stage_lstm_weight/epoch_22_0.17005.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1427 - mse: 0.1427 - mae: 0.2957 - val_loss: 0.1700 - val_mse: 0.1700 - val_mae: 0.3265
# Epoch 23/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1421 - mse: 0.1421 - mae: 0.2950
# Epoch 23: val_loss improved from 0.17005 to 0.16899, saving model to models/first_stage_lstm_weight/epoch_23_0.16899.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1420 - mse: 0.1420 - mae: 0.2948 - val_loss: 0.1690 - val_mse: 0.1690 - val_mae: 0.3278
# Epoch 24/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1413 - mse: 0.1413 - mae: 0.2939
# Epoch 24: val_loss did not improve from 0.16899
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1414 - mse: 0.1414 - mae: 0.2940 - val_loss: 0.1692 - val_mse: 0.1692 - val_mae: 0.3262
# Epoch 25/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.1408 - mse: 0.1408 - mae: 0.2932
# Epoch 25: val_loss improved from 0.16899 to 0.16859, saving model to models/first_stage_lstm_weight/epoch_25_0.16859.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1407 - mse: 0.1407 - mae: 0.2931 - val_loss: 0.1686 - val_mse: 0.1686 - val_mae: 0.3265
# Epoch 26/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1403 - mse: 0.1403 - mae: 0.2924
# Epoch 26: val_loss improved from 0.16859 to 0.16788, saving model to models/first_stage_lstm_weight/epoch_26_0.16788.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1403 - mse: 0.1403 - mae: 0.2923 - val_loss: 0.1679 - val_mse: 0.1679 - val_mae: 0.3257
# Epoch 27/3000
# 212/218 [============================>.] - ETA: 0s - loss: 0.1395 - mse: 0.1395 - mae: 0.2912
# Epoch 27: val_loss improved from 0.16788 to 0.16652, saving model to models/first_stage_lstm_weight/epoch_27_0.16652.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1395 - mse: 0.1395 - mae: 0.2912 - val_loss: 0.1665 - val_mse: 0.1665 - val_mae: 0.3253
# Epoch 28/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1388 - mse: 0.1388 - mae: 0.2901
# Epoch 28: val_loss did not improve from 0.16652
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1389 - mse: 0.1389 - mae: 0.2903 - val_loss: 0.1667 - val_mse: 0.1667 - val_mae: 0.3240
# Epoch 29/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1384 - mse: 0.1384 - mae: 0.2896
# Epoch 29: val_loss improved from 0.16652 to 0.16618, saving model to models/first_stage_lstm_weight/epoch_29_0.16618.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1384 - mse: 0.1384 - mae: 0.2897 - val_loss: 0.1662 - val_mse: 0.1662 - val_mae: 0.3237
# Epoch 30/3000
# 212/218 [============================>.] - ETA: 0s - loss: 0.1378 - mse: 0.1378 - mae: 0.2886
# Epoch 30: val_loss improved from 0.16618 to 0.16601, saving model to models/first_stage_lstm_weight/epoch_30_0.16601.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1376 - mse: 0.1376 - mae: 0.2884 - val_loss: 0.1660 - val_mse: 0.1660 - val_mae: 0.3238
# Epoch 31/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1371 - mse: 0.1371 - mae: 0.2874
# Epoch 31: val_loss improved from 0.16601 to 0.16550, saving model to models/first_stage_lstm_weight/epoch_31_0.16550.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1370 - mse: 0.1370 - mae: 0.2874 - val_loss: 0.1655 - val_mse: 0.1655 - val_mae: 0.3231
# Epoch 32/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.1356 - mse: 0.1356 - mae: 0.2858
# Epoch 32: val_loss did not improve from 0.16550
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1363 - mse: 0.1363 - mae: 0.2865 - val_loss: 0.1659 - val_mse: 0.1659 - val_mae: 0.3229
# Epoch 33/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1357 - mse: 0.1357 - mae: 0.2854
# Epoch 33: val_loss improved from 0.16550 to 0.16311, saving model to models/first_stage_lstm_weight/epoch_33_0.16311.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1357 - mse: 0.1357 - mae: 0.2854 - val_loss: 0.1631 - val_mse: 0.1631 - val_mae: 0.3195
# Epoch 34/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1352 - mse: 0.1352 - mae: 0.2848
# Epoch 34: val_loss improved from 0.16311 to 0.16256, saving model to models/first_stage_lstm_weight/epoch_34_0.16256.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1351 - mse: 0.1351 - mae: 0.2846 - val_loss: 0.1626 - val_mse: 0.1626 - val_mae: 0.3196
# Epoch 35/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1341 - mse: 0.1341 - mae: 0.2832
# Epoch 35: val_loss improved from 0.16256 to 0.16126, saving model to models/first_stage_lstm_weight/epoch_35_0.16126.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1341 - mse: 0.1341 - mae: 0.2833 - val_loss: 0.1613 - val_mse: 0.1613 - val_mae: 0.3169
# Epoch 36/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1337 - mse: 0.1337 - mae: 0.2828
# Epoch 36: val_loss did not improve from 0.16126
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1337 - mse: 0.1337 - mae: 0.2828 - val_loss: 0.1626 - val_mse: 0.1626 - val_mae: 0.3181
# Epoch 37/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1264 - mse: 0.1264 - mae: 0.2752
# Epoch 37: val_loss improved from 0.16126 to 0.14997, saving model to models/first_stage_lstm_weight/epoch_37_0.14997.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1262 - mse: 0.1262 - mae: 0.2750 - val_loss: 0.1500 - val_mse: 0.1500 - val_mae: 0.3062
# Epoch 38/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.1222 - mse: 0.1222 - mae: 0.2698
# Epoch 38: val_loss improved from 0.14997 to 0.14610, saving model to models/first_stage_lstm_weight/epoch_38_0.14610.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1221 - mse: 0.1221 - mae: 0.2698 - val_loss: 0.1461 - val_mse: 0.1461 - val_mae: 0.3015
# Epoch 39/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.1215 - mse: 0.1215 - mae: 0.2690
# Epoch 39: val_loss did not improve from 0.14610
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1209 - mse: 0.1209 - mae: 0.2682 - val_loss: 0.1466 - val_mse: 0.1466 - val_mae: 0.3010
# Epoch 40/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1200 - mse: 0.1200 - mae: 0.2664
# Epoch 40: val_loss improved from 0.14610 to 0.14487, saving model to models/first_stage_lstm_weight/epoch_40_0.14487.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1199 - mse: 0.1199 - mae: 0.2663 - val_loss: 0.1449 - val_mse: 0.1449 - val_mae: 0.2972
# Epoch 41/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1194 - mse: 0.1194 - mae: 0.2654
# Epoch 41: val_loss improved from 0.14487 to 0.14347, saving model to models/first_stage_lstm_weight/epoch_41_0.14347.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1194 - mse: 0.1194 - mae: 0.2654 - val_loss: 0.1435 - val_mse: 0.1435 - val_mae: 0.2967
# Epoch 42/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1184 - mse: 0.1184 - mae: 0.2638
# Epoch 42: val_loss improved from 0.14347 to 0.14191, saving model to models/first_stage_lstm_weight/epoch_42_0.14191.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1184 - mse: 0.1184 - mae: 0.2638 - val_loss: 0.1419 - val_mse: 0.1419 - val_mae: 0.2938
# Epoch 43/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1178 - mse: 0.1178 - mae: 0.2628
# Epoch 43: val_loss did not improve from 0.14191
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1177 - mse: 0.1177 - mae: 0.2627 - val_loss: 0.1436 - val_mse: 0.1436 - val_mae: 0.2963
# Epoch 44/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.1178 - mse: 0.1178 - mae: 0.2627
# Epoch 44: val_loss improved from 0.14191 to 0.14139, saving model to models/first_stage_lstm_weight/epoch_44_0.14139.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1173 - mse: 0.1173 - mae: 0.2619 - val_loss: 0.1414 - val_mse: 0.1414 - val_mae: 0.2928
# Epoch 45/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1165 - mse: 0.1165 - mae: 0.2605
# Epoch 45: val_loss improved from 0.14139 to 0.14119, saving model to models/first_stage_lstm_weight/epoch_45_0.14119.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1165 - mse: 0.1165 - mae: 0.2604 - val_loss: 0.1412 - val_mse: 0.1412 - val_mae: 0.2919
# Epoch 46/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.1159 - mse: 0.1159 - mae: 0.2593
# Epoch 46: val_loss improved from 0.14119 to 0.13851, saving model to models/first_stage_lstm_weight/epoch_46_0.13851.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1160 - mse: 0.1160 - mae: 0.2595 - val_loss: 0.1385 - val_mse: 0.1385 - val_mae: 0.2890
# Epoch 47/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.1154 - mse: 0.1154 - mae: 0.2583
# Epoch 47: val_loss did not improve from 0.13851
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1155 - mse: 0.1155 - mae: 0.2586 - val_loss: 0.1394 - val_mse: 0.1394 - val_mae: 0.2897
# Epoch 48/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1150 - mse: 0.1150 - mae: 0.2576
# Epoch 48: val_loss did not improve from 0.13851
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1150 - mse: 0.1150 - mae: 0.2577 - val_loss: 0.1390 - val_mse: 0.1390 - val_mae: 0.2884
# Epoch 49/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1148 - mse: 0.1148 - mae: 0.2573
# Epoch 49: val_loss did not improve from 0.13851
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1147 - mse: 0.1147 - mae: 0.2571 - val_loss: 0.1392 - val_mse: 0.1392 - val_mae: 0.2895
# Epoch 50/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1141 - mse: 0.1141 - mae: 0.2560
# Epoch 50: val_loss improved from 0.13851 to 0.13655, saving model to models/first_stage_lstm_weight/epoch_50_0.13655.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1142 - mse: 0.1142 - mae: 0.2561 - val_loss: 0.1365 - val_mse: 0.1365 - val_mae: 0.2845
# Epoch 51/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1137 - mse: 0.1137 - mae: 0.2553
# Epoch 51: val_loss improved from 0.13655 to 0.13632, saving model to models/first_stage_lstm_weight/epoch_51_0.13632.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1137 - mse: 0.1137 - mae: 0.2553 - val_loss: 0.1363 - val_mse: 0.1363 - val_mae: 0.2858
# Epoch 52/3000
# 212/218 [============================>.] - ETA: 0s - loss: 0.1127 - mse: 0.1127 - mae: 0.2533
# Epoch 52: val_loss did not improve from 0.13632
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1129 - mse: 0.1129 - mae: 0.2536 - val_loss: 0.1365 - val_mse: 0.1365 - val_mae: 0.2851
# Epoch 53/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1124 - mse: 0.1124 - mae: 0.2528
# Epoch 53: val_loss improved from 0.13632 to 0.13592, saving model to models/first_stage_lstm_weight/epoch_53_0.13592.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1123 - mse: 0.1123 - mae: 0.2528 - val_loss: 0.1359 - val_mse: 0.1359 - val_mae: 0.2847
# Epoch 54/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.1119 - mse: 0.1119 - mae: 0.2520
# Epoch 54: val_loss improved from 0.13592 to 0.13576, saving model to models/first_stage_lstm_weight/epoch_54_0.13576.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1117 - mse: 0.1117 - mae: 0.2518 - val_loss: 0.1358 - val_mse: 0.1358 - val_mae: 0.2836
# Epoch 55/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1109 - mse: 0.1109 - mae: 0.2505
# Epoch 55: val_loss improved from 0.13576 to 0.13245, saving model to models/first_stage_lstm_weight/epoch_55_0.13245.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1111 - mse: 0.1111 - mae: 0.2507 - val_loss: 0.1325 - val_mse: 0.1325 - val_mae: 0.2814
# Epoch 56/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.1105 - mse: 0.1105 - mae: 0.2498
# Epoch 56: val_loss did not improve from 0.13245
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1104 - mse: 0.1104 - mae: 0.2498 - val_loss: 0.1335 - val_mse: 0.1335 - val_mae: 0.2811
# Epoch 57/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1097 - mse: 0.1097 - mae: 0.2487
# Epoch 57: val_loss did not improve from 0.13245
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1097 - mse: 0.1097 - mae: 0.2487 - val_loss: 0.1343 - val_mse: 0.1343 - val_mae: 0.2818
# Epoch 58/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1093 - mse: 0.1093 - mae: 0.2481
# Epoch 58: val_loss improved from 0.13245 to 0.13167, saving model to models/first_stage_lstm_weight/epoch_58_0.13167.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1093 - mse: 0.1093 - mae: 0.2481 - val_loss: 0.1317 - val_mse: 0.1317 - val_mae: 0.2789
# Epoch 59/3000
# 210/218 [===========================>..] - ETA: 0s - loss: 0.1087 - mse: 0.1087 - mae: 0.2472
# Epoch 59: val_loss did not improve from 0.13167
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1088 - mse: 0.1088 - mae: 0.2473 - val_loss: 0.1326 - val_mse: 0.1326 - val_mae: 0.2803
# Epoch 60/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.1084 - mse: 0.1084 - mae: 0.2466
# Epoch 60: val_loss improved from 0.13167 to 0.13145, saving model to models/first_stage_lstm_weight/epoch_60_0.13145.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1082 - mse: 0.1082 - mae: 0.2464 - val_loss: 0.1315 - val_mse: 0.1315 - val_mae: 0.2777
# Epoch 61/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1079 - mse: 0.1079 - mae: 0.2461
# Epoch 61: val_loss did not improve from 0.13145
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1080 - mse: 0.1080 - mae: 0.2462 - val_loss: 0.1333 - val_mse: 0.1333 - val_mae: 0.2787
# Epoch 62/3000
# 200/218 [==========================>...] - ETA: 0s - loss: 0.1079 - mse: 0.1079 - mae: 0.2458
# Epoch 62: val_loss improved from 0.13145 to 0.13112, saving model to models/first_stage_lstm_weight/epoch_62_0.13112.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1074 - mse: 0.1074 - mae: 0.2450 - val_loss: 0.1311 - val_mse: 0.1311 - val_mae: 0.2767
# Epoch 63/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.1072 - mse: 0.1072 - mae: 0.2451
# Epoch 63: val_loss did not improve from 0.13112
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1071 - mse: 0.1071 - mae: 0.2448 - val_loss: 0.1315 - val_mse: 0.1315 - val_mae: 0.2780
# Epoch 64/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1068 - mse: 0.1068 - mae: 0.2445
# Epoch 64: val_loss improved from 0.13112 to 0.13073, saving model to models/first_stage_lstm_weight/epoch_64_0.13073.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1069 - mse: 0.1069 - mae: 0.2446 - val_loss: 0.1307 - val_mse: 0.1307 - val_mae: 0.2763
# Epoch 65/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1067 - mse: 0.1067 - mae: 0.2443
# Epoch 65: val_loss improved from 0.13073 to 0.13025, saving model to models/first_stage_lstm_weight/epoch_65_0.13025.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1067 - mse: 0.1067 - mae: 0.2443 - val_loss: 0.1302 - val_mse: 0.1302 - val_mae: 0.2762
# Epoch 66/3000
# 205/218 [===========================>..] - ETA: 0s - loss: 0.1063 - mse: 0.1063 - mae: 0.2438
# Epoch 66: val_loss improved from 0.13025 to 0.12949, saving model to models/first_stage_lstm_weight/epoch_66_0.12949.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1063 - mse: 0.1063 - mae: 0.2437 - val_loss: 0.1295 - val_mse: 0.1295 - val_mae: 0.2752
# Epoch 67/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.1056 - mse: 0.1056 - mae: 0.2429
# Epoch 67: val_loss did not improve from 0.12949
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1061 - mse: 0.1061 - mae: 0.2434 - val_loss: 0.1305 - val_mse: 0.1305 - val_mae: 0.2774
# Epoch 68/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.1056 - mse: 0.1056 - mae: 0.2423
# Epoch 68: val_loss did not improve from 0.12949
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1057 - mse: 0.1057 - mae: 0.2426 - val_loss: 0.1295 - val_mse: 0.1295 - val_mae: 0.2762
# Epoch 69/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.1054 - mse: 0.1054 - mae: 0.2423
# Epoch 69: val_loss did not improve from 0.12949
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1055 - mse: 0.1055 - mae: 0.2425 - val_loss: 0.1300 - val_mse: 0.1300 - val_mae: 0.2758
# Epoch 70/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.1053 - mse: 0.1053 - mae: 0.2420
# Epoch 70: val_loss did not improve from 0.12949
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1052 - mse: 0.1052 - mae: 0.2419 - val_loss: 0.1295 - val_mse: 0.1295 - val_mae: 0.2757
# Epoch 71/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.1054 - mse: 0.1054 - mae: 0.2422
# Epoch 71: val_loss improved from 0.12949 to 0.12926, saving model to models/first_stage_lstm_weight/epoch_71_0.12926.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1050 - mse: 0.1050 - mae: 0.2417 - val_loss: 0.1293 - val_mse: 0.1293 - val_mae: 0.2744
# Epoch 72/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.1053 - mse: 0.1053 - mae: 0.2419
# Epoch 72: val_loss did not improve from 0.12926
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1047 - mse: 0.1047 - mae: 0.2411 - val_loss: 0.1299 - val_mse: 0.1299 - val_mae: 0.2754
# Epoch 73/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.1046 - mse: 0.1046 - mae: 0.2409
# Epoch 73: val_loss did not improve from 0.12926
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1046 - mse: 0.1046 - mae: 0.2409 - val_loss: 0.1296 - val_mse: 0.1296 - val_mae: 0.2752
# Epoch 74/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1042 - mse: 0.1042 - mae: 0.2404
# Epoch 74: val_loss did not improve from 0.12926
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1042 - mse: 0.1042 - mae: 0.2404 - val_loss: 0.1293 - val_mse: 0.1293 - val_mae: 0.2756
# Epoch 75/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1040 - mse: 0.1040 - mae: 0.2401
# Epoch 75: val_loss improved from 0.12926 to 0.12904, saving model to models/first_stage_lstm_weight/epoch_75_0.12904.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1040 - mse: 0.1040 - mae: 0.2400 - val_loss: 0.1290 - val_mse: 0.1290 - val_mae: 0.2745
# Epoch 76/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1040 - mse: 0.1040 - mae: 0.2401
# Epoch 76: val_loss improved from 0.12904 to 0.12846, saving model to models/first_stage_lstm_weight/epoch_76_0.12846.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1039 - mse: 0.1039 - mae: 0.2399 - val_loss: 0.1285 - val_mse: 0.1285 - val_mae: 0.2750
# Epoch 77/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1035 - mse: 0.1035 - mae: 0.2392
# Epoch 77: val_loss did not improve from 0.12846
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1035 - mse: 0.1035 - mae: 0.2391 - val_loss: 0.1293 - val_mse: 0.1293 - val_mae: 0.2753
# Epoch 78/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1031 - mse: 0.1031 - mae: 0.2385
# Epoch 78: val_loss improved from 0.12846 to 0.12786, saving model to models/first_stage_lstm_weight/epoch_78_0.12786.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1031 - mse: 0.1031 - mae: 0.2386 - val_loss: 0.1279 - val_mse: 0.1279 - val_mae: 0.2727
# Epoch 79/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1030 - mse: 0.1030 - mae: 0.2386
# Epoch 79: val_loss improved from 0.12786 to 0.12724, saving model to models/first_stage_lstm_weight/epoch_79_0.12724.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1030 - mse: 0.1030 - mae: 0.2386 - val_loss: 0.1272 - val_mse: 0.1272 - val_mae: 0.2725
# Epoch 80/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1026 - mse: 0.1026 - mae: 0.2377
# Epoch 80: val_loss did not improve from 0.12724
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1026 - mse: 0.1026 - mae: 0.2377 - val_loss: 0.1286 - val_mse: 0.1286 - val_mae: 0.2741
# Epoch 81/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.1021 - mse: 0.1021 - mae: 0.2369
# Epoch 81: val_loss did not improve from 0.12724
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1021 - mse: 0.1021 - mae: 0.2369 - val_loss: 0.1277 - val_mse: 0.1277 - val_mae: 0.2748
# Epoch 82/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1018 - mse: 0.1018 - mae: 0.2365
# Epoch 82: val_loss improved from 0.12724 to 0.12606, saving model to models/first_stage_lstm_weight/epoch_82_0.12606.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1018 - mse: 0.1018 - mae: 0.2365 - val_loss: 0.1261 - val_mse: 0.1261 - val_mae: 0.2706
# Epoch 83/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1018 - mse: 0.1018 - mae: 0.2363
# Epoch 83: val_loss improved from 0.12606 to 0.12604, saving model to models/first_stage_lstm_weight/epoch_83_0.12604.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1016 - mse: 0.1016 - mae: 0.2361 - val_loss: 0.1260 - val_mse: 0.1260 - val_mae: 0.2708
# Epoch 84/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.1012 - mse: 0.1012 - mae: 0.2354
# Epoch 84: val_loss improved from 0.12604 to 0.12543, saving model to models/first_stage_lstm_weight/epoch_84_0.12543.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1012 - mse: 0.1012 - mae: 0.2355 - val_loss: 0.1254 - val_mse: 0.1254 - val_mae: 0.2727
# Epoch 85/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.1006 - mse: 0.1006 - mae: 0.2347
# Epoch 85: val_loss did not improve from 0.12543
# 218/218 [==============================] - 1s 4ms/step - loss: 0.1006 - mse: 0.1006 - mae: 0.2346 - val_loss: 0.1259 - val_mse: 0.1259 - val_mae: 0.2721
# Epoch 86/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.1002 - mse: 0.1002 - mae: 0.2337
# Epoch 86: val_loss improved from 0.12543 to 0.12457, saving model to models/first_stage_lstm_weight/epoch_86_0.12457.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.1002 - mse: 0.1002 - mae: 0.2337 - val_loss: 0.1246 - val_mse: 0.1246 - val_mae: 0.2693
# Epoch 87/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0996 - mse: 0.0996 - mae: 0.2327
# Epoch 87: val_loss did not improve from 0.12457
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0996 - mse: 0.0996 - mae: 0.2327 - val_loss: 0.1248 - val_mse: 0.1248 - val_mae: 0.2689
# Epoch 88/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.0991 - mse: 0.0991 - mae: 0.2319
# Epoch 88: val_loss improved from 0.12457 to 0.12406, saving model to models/first_stage_lstm_weight/epoch_88_0.12406.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0992 - mse: 0.0992 - mae: 0.2321 - val_loss: 0.1241 - val_mse: 0.1241 - val_mae: 0.2684
# Epoch 89/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0984 - mse: 0.0984 - mae: 0.2304
# Epoch 89: val_loss improved from 0.12406 to 0.12159, saving model to models/first_stage_lstm_weight/epoch_89_0.12159.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0984 - mse: 0.0984 - mae: 0.2305 - val_loss: 0.1216 - val_mse: 0.1216 - val_mae: 0.2652
# Epoch 90/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0981 - mse: 0.0981 - mae: 0.2299
# Epoch 90: val_loss did not improve from 0.12159
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0979 - mse: 0.0979 - mae: 0.2296 - val_loss: 0.1228 - val_mse: 0.1228 - val_mae: 0.2667
# Epoch 91/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.0974 - mse: 0.0974 - mae: 0.2283
# Epoch 91: val_loss improved from 0.12159 to 0.11933, saving model to models/first_stage_lstm_weight/epoch_91_0.11933.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0974 - mse: 0.0974 - mae: 0.2283 - val_loss: 0.1193 - val_mse: 0.1193 - val_mae: 0.2617
# Epoch 92/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0969 - mse: 0.0969 - mae: 0.2274
# Epoch 92: val_loss did not improve from 0.11933
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0968 - mse: 0.0968 - mae: 0.2272 - val_loss: 0.1194 - val_mse: 0.1194 - val_mae: 0.2632
# Epoch 93/3000
# 210/218 [===========================>..] - ETA: 0s - loss: 0.0963 - mse: 0.0963 - mae: 0.2260
# Epoch 93: val_loss improved from 0.11933 to 0.11805, saving model to models/first_stage_lstm_weight/epoch_93_0.11805.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0963 - mse: 0.0963 - mae: 0.2263 - val_loss: 0.1180 - val_mse: 0.1180 - val_mae: 0.2591
# Epoch 94/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0962 - mse: 0.0962 - mae: 0.2258
# Epoch 94: val_loss did not improve from 0.11805
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0962 - mse: 0.0962 - mae: 0.2258 - val_loss: 0.1180 - val_mse: 0.1180 - val_mae: 0.2590
# Epoch 95/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.0954 - mse: 0.0954 - mae: 0.2247
# Epoch 95: val_loss improved from 0.11805 to 0.11660, saving model to models/first_stage_lstm_weight/epoch_95_0.11660.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0955 - mse: 0.0955 - mae: 0.2246 - val_loss: 0.1166 - val_mse: 0.1166 - val_mae: 0.2568
# Epoch 96/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0950 - mse: 0.0950 - mae: 0.2235
# Epoch 96: val_loss improved from 0.11660 to 0.11623, saving model to models/first_stage_lstm_weight/epoch_96_0.11623.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0950 - mse: 0.0950 - mae: 0.2235 - val_loss: 0.1162 - val_mse: 0.1162 - val_mae: 0.2560
# Epoch 97/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0943 - mse: 0.0943 - mae: 0.2223
# Epoch 97: val_loss improved from 0.11623 to 0.11505, saving model to models/first_stage_lstm_weight/epoch_97_0.11505.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0944 - mse: 0.0944 - mae: 0.2224 - val_loss: 0.1150 - val_mse: 0.1150 - val_mae: 0.2536
# Epoch 98/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.0938 - mse: 0.0938 - mae: 0.2211
# Epoch 98: val_loss improved from 0.11505 to 0.11452, saving model to models/first_stage_lstm_weight/epoch_98_0.11452.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0939 - mse: 0.0939 - mae: 0.2214 - val_loss: 0.1145 - val_mse: 0.1145 - val_mae: 0.2522
# Epoch 99/3000
# 204/218 [===========================>..] - ETA: 0s - loss: 0.0936 - mse: 0.0936 - mae: 0.2207
# Epoch 99: val_loss did not improve from 0.11452
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0936 - mse: 0.0936 - mae: 0.2207 - val_loss: 0.1148 - val_mse: 0.1148 - val_mae: 0.2535
# Epoch 100/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.0929 - mse: 0.0929 - mae: 0.2191
# Epoch 100: val_loss improved from 0.11452 to 0.11337, saving model to models/first_stage_lstm_weight/epoch_100_0.11337.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0929 - mse: 0.0929 - mae: 0.2190 - val_loss: 0.1134 - val_mse: 0.1134 - val_mae: 0.2515
# Epoch 101/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.0929 - mse: 0.0929 - mae: 0.2189
# Epoch 101: val_loss did not improve from 0.11337
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0928 - mse: 0.0928 - mae: 0.2189 - val_loss: 0.1134 - val_mse: 0.1134 - val_mae: 0.2516
# Epoch 102/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.0928 - mse: 0.0928 - mae: 0.2187
# Epoch 102: val_loss improved from 0.11337 to 0.11165, saving model to models/first_stage_lstm_weight/epoch_102_0.11165.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0926 - mse: 0.0926 - mae: 0.2183 - val_loss: 0.1116 - val_mse: 0.1116 - val_mae: 0.2478
# Epoch 103/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.0923 - mse: 0.0923 - mae: 0.2174
# Epoch 103: val_loss improved from 0.11165 to 0.11164, saving model to models/first_stage_lstm_weight/epoch_103_0.11164.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0920 - mse: 0.0920 - mae: 0.2171 - val_loss: 0.1116 - val_mse: 0.1116 - val_mae: 0.2481
# Epoch 104/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0917 - mse: 0.0917 - mae: 0.2163
# Epoch 104: val_loss did not improve from 0.11164
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0918 - mse: 0.0918 - mae: 0.2164 - val_loss: 0.1123 - val_mse: 0.1123 - val_mae: 0.2496
# Epoch 105/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0917 - mse: 0.0917 - mae: 0.2162
# Epoch 105: val_loss did not improve from 0.11164
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0917 - mse: 0.0917 - mae: 0.2162 - val_loss: 0.1118 - val_mse: 0.1118 - val_mae: 0.2477
# Epoch 106/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0911 - mse: 0.0911 - mae: 0.2150
# Epoch 106: val_loss improved from 0.11164 to 0.11037, saving model to models/first_stage_lstm_weight/epoch_106_0.11037.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0912 - mse: 0.0912 - mae: 0.2151 - val_loss: 0.1104 - val_mse: 0.1104 - val_mae: 0.2455
# Epoch 107/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0911 - mse: 0.0911 - mae: 0.2151
# Epoch 107: val_loss did not improve from 0.11037
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0911 - mse: 0.0911 - mae: 0.2152 - val_loss: 0.1104 - val_mse: 0.1104 - val_mae: 0.2465
# Epoch 108/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0909 - mse: 0.0909 - mae: 0.2146
# Epoch 108: val_loss improved from 0.11037 to 0.11012, saving model to models/first_stage_lstm_weight/epoch_108_0.11012.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0909 - mse: 0.0909 - mae: 0.2145 - val_loss: 0.1101 - val_mse: 0.1101 - val_mae: 0.2453
# Epoch 109/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0908 - mse: 0.0908 - mae: 0.2142
# Epoch 109: val_loss did not improve from 0.11012
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0907 - mse: 0.0907 - mae: 0.2141 - val_loss: 0.1106 - val_mse: 0.1106 - val_mae: 0.2454
# Epoch 110/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0905 - mse: 0.0905 - mae: 0.2137
# Epoch 110: val_loss improved from 0.11012 to 0.10976, saving model to models/first_stage_lstm_weight/epoch_110_0.10976.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0905 - mse: 0.0905 - mae: 0.2137 - val_loss: 0.1098 - val_mse: 0.1098 - val_mae: 0.2439
# Epoch 111/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.0905 - mse: 0.0905 - mae: 0.2136
# Epoch 111: val_loss improved from 0.10976 to 0.10921, saving model to models/first_stage_lstm_weight/epoch_111_0.10921.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0903 - mse: 0.0903 - mae: 0.2133 - val_loss: 0.1092 - val_mse: 0.1092 - val_mae: 0.2431
# Epoch 112/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.0904 - mse: 0.0904 - mae: 0.2135
# Epoch 112: val_loss improved from 0.10921 to 0.10873, saving model to models/first_stage_lstm_weight/epoch_112_0.10873.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0903 - mse: 0.0903 - mae: 0.2134 - val_loss: 0.1087 - val_mse: 0.1087 - val_mae: 0.2440
# Epoch 113/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.0901 - mse: 0.0901 - mae: 0.2129
# Epoch 113: val_loss improved from 0.10873 to 0.10829, saving model to models/first_stage_lstm_weight/epoch_113_0.10829.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0900 - mse: 0.0900 - mae: 0.2129 - val_loss: 0.1083 - val_mse: 0.1083 - val_mae: 0.2432
# Epoch 114/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0899 - mse: 0.0899 - mae: 0.2126
# Epoch 114: val_loss did not improve from 0.10829
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0899 - mse: 0.0899 - mae: 0.2126 - val_loss: 0.1085 - val_mse: 0.1085 - val_mae: 0.2436
# Epoch 115/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0894 - mse: 0.0894 - mae: 0.2116
# Epoch 115: val_loss did not improve from 0.10829
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0895 - mse: 0.0895 - mae: 0.2117 - val_loss: 0.1085 - val_mse: 0.1085 - val_mae: 0.2438
# Epoch 116/3000
# 211/218 [============================>.] - ETA: 0s - loss: 0.0896 - mse: 0.0896 - mae: 0.2119
# Epoch 116: val_loss improved from 0.10829 to 0.10697, saving model to models/first_stage_lstm_weight/epoch_116_0.10697.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0895 - mse: 0.0895 - mae: 0.2118 - val_loss: 0.1070 - val_mse: 0.1070 - val_mae: 0.2398
# Epoch 117/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0893 - mse: 0.0893 - mae: 0.2112
# Epoch 117: val_loss did not improve from 0.10697
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0892 - mse: 0.0892 - mae: 0.2111 - val_loss: 0.1081 - val_mse: 0.1081 - val_mae: 0.2417
# Epoch 118/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.0888 - mse: 0.0888 - mae: 0.2104
# Epoch 118: val_loss did not improve from 0.10697
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0890 - mse: 0.0890 - mae: 0.2106 - val_loss: 0.1084 - val_mse: 0.1084 - val_mae: 0.2429
# Epoch 119/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.0889 - mse: 0.0889 - mae: 0.2105
# Epoch 119: val_loss did not improve from 0.10697
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0888 - mse: 0.0888 - mae: 0.2104 - val_loss: 0.1074 - val_mse: 0.1074 - val_mae: 0.2419
# Epoch 120/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0887 - mse: 0.0887 - mae: 0.2103
# Epoch 120: val_loss improved from 0.10697 to 0.10667, saving model to models/first_stage_lstm_weight/epoch_120_0.10667.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0887 - mse: 0.0887 - mae: 0.2103 - val_loss: 0.1067 - val_mse: 0.1067 - val_mae: 0.2400
# Epoch 121/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0885 - mse: 0.0885 - mae: 0.2096
# Epoch 121: val_loss improved from 0.10667 to 0.10619, saving model to models/first_stage_lstm_weight/epoch_121_0.10619.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0885 - mse: 0.0885 - mae: 0.2096 - val_loss: 0.1062 - val_mse: 0.1062 - val_mae: 0.2380
# Epoch 122/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0881 - mse: 0.0881 - mae: 0.2088
# Epoch 122: val_loss improved from 0.10619 to 0.10532, saving model to models/first_stage_lstm_weight/epoch_122_0.10532.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0880 - mse: 0.0880 - mae: 0.2087 - val_loss: 0.1053 - val_mse: 0.1053 - val_mae: 0.2382
# Epoch 123/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0877 - mse: 0.0877 - mae: 0.2081
# Epoch 123: val_loss improved from 0.10532 to 0.10399, saving model to models/first_stage_lstm_weight/epoch_123_0.10399.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0877 - mse: 0.0877 - mae: 0.2081 - val_loss: 0.1040 - val_mse: 0.1040 - val_mae: 0.2358
# Epoch 124/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0875 - mse: 0.0875 - mae: 0.2075
# Epoch 124: val_loss did not improve from 0.10399
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0875 - mse: 0.0875 - mae: 0.2075 - val_loss: 0.1044 - val_mse: 0.1044 - val_mae: 0.2355
# Epoch 125/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0874 - mse: 0.0874 - mae: 0.2073
# Epoch 125: val_loss improved from 0.10399 to 0.10396, saving model to models/first_stage_lstm_weight/epoch_125_0.10396.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0874 - mse: 0.0874 - mae: 0.2072 - val_loss: 0.1040 - val_mse: 0.1040 - val_mae: 0.2353
# Epoch 126/3000
# 214/218 [============================>.] - ETA: 0s - loss: 0.0870 - mse: 0.0870 - mae: 0.2062
# Epoch 126: val_loss did not improve from 0.10396
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0870 - mse: 0.0870 - mae: 0.2062 - val_loss: 0.1044 - val_mse: 0.1044 - val_mae: 0.2356
# Epoch 127/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0868 - mse: 0.0868 - mae: 0.2058
# Epoch 127: val_loss improved from 0.10396 to 0.10370, saving model to models/first_stage_lstm_weight/epoch_127_0.10370.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0868 - mse: 0.0868 - mae: 0.2058 - val_loss: 0.1037 - val_mse: 0.1037 - val_mae: 0.2351
# Epoch 128/3000
# 213/218 [============================>.] - ETA: 0s - loss: 0.0866 - mse: 0.0866 - mae: 0.2054
# Epoch 128: val_loss did not improve from 0.10370
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0866 - mse: 0.0866 - mae: 0.2054 - val_loss: 0.1037 - val_mse: 0.1037 - val_mae: 0.2351
# Epoch 129/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.0866 - mse: 0.0866 - mae: 0.2056
# Epoch 129: val_loss improved from 0.10370 to 0.10251, saving model to models/first_stage_lstm_weight/epoch_129_0.10251.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0865 - mse: 0.0865 - mae: 0.2054 - val_loss: 0.1025 - val_mse: 0.1025 - val_mae: 0.2327
# Epoch 130/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0860 - mse: 0.0860 - mae: 0.2042
# Epoch 130: val_loss did not improve from 0.10251
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0862 - mse: 0.0862 - mae: 0.2043 - val_loss: 0.1035 - val_mse: 0.1035 - val_mae: 0.2337
# Epoch 131/3000
# 212/218 [============================>.] - ETA: 0s - loss: 0.0861 - mse: 0.0861 - mae: 0.2044
# Epoch 131: val_loss did not improve from 0.10251
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0861 - mse: 0.0861 - mae: 0.2043 - val_loss: 0.1030 - val_mse: 0.1030 - val_mae: 0.2330
# Epoch 132/3000
# 211/218 [============================>.] - ETA: 0s - loss: 0.0861 - mse: 0.0861 - mae: 0.2044
# Epoch 132: val_loss improved from 0.10251 to 0.10218, saving model to models/first_stage_lstm_weight/epoch_132_0.10218.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0862 - mse: 0.0862 - mae: 0.2044 - val_loss: 0.1022 - val_mse: 0.1022 - val_mae: 0.2316
# Epoch 133/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0857 - mse: 0.0857 - mae: 0.2033
# Epoch 133: val_loss did not improve from 0.10218
# ...
# Epoch 315/3000
# 212/218 [============================>.] - ETA: 0s - loss: 0.0678 - mse: 0.0678 - mae: 0.1536
# Epoch 315: val_loss did not improve from 0.07668
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0677 - mse: 0.0677 - mae: 0.1534 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.1747
# Epoch 316/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0676 - mse: 0.0676 - mae: 0.1529
# Epoch 316: val_loss did not improve from 0.07668
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1529 - val_loss: 0.0774 - val_mse: 0.0774 - val_mae: 0.1750
# Epoch 317/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.0675 - mse: 0.0675 - mae: 0.1529
# Epoch 317: val_loss improved from 0.07668 to 0.07667, saving model to models/first_stage_lstm_weight/epoch_317_0.07667.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1531 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.1724
# Epoch 318/3000
# 200/218 [==========================>...] - ETA: 0s - loss: 0.0677 - mse: 0.0677 - mae: 0.1526
# Epoch 318: val_loss did not improve from 0.07667
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1526 - val_loss: 0.0781 - val_mse: 0.0781 - val_mae: 0.1813
# Epoch 319/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0676 - mse: 0.0676 - mae: 0.1530
# Epoch 319: val_loss did not improve from 0.07667
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1530 - val_loss: 0.0769 - val_mse: 0.0769 - val_mae: 0.1745
# Epoch 320/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0676 - mse: 0.0676 - mae: 0.1526
# Epoch 320: val_loss did not improve from 0.07667
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1525 - val_loss: 0.0775 - val_mse: 0.0775 - val_mae: 0.1759
# Epoch 321/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0676 - mse: 0.0676 - mae: 0.1526
# Epoch 321: val_loss did not improve from 0.07667
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1526 - val_loss: 0.0776 - val_mse: 0.0776 - val_mae: 0.1777
# Epoch 322/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0675 - mse: 0.0675 - mae: 0.1520
# Epoch 322: val_loss improved from 0.07667 to 0.07663, saving model to models/first_stage_lstm_weight/epoch_322_0.07663.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1519 - val_loss: 0.0766 - val_mse: 0.0766 - val_mae: 0.1729
# Epoch 323/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1518
# Epoch 323: val_loss improved from 0.07663 to 0.07613, saving model to models/first_stage_lstm_weight/epoch_323_0.07613.h5
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1518 - val_loss: 0.0761 - val_mse: 0.0761 - val_mae: 0.1710
# Epoch 324/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0676 - mse: 0.0676 - mae: 0.1523
# Epoch 324: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0675 - mse: 0.0675 - mae: 0.1523 - val_loss: 0.0774 - val_mse: 0.0774 - val_mae: 0.1754
# Epoch 325/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0675 - mse: 0.0675 - mae: 0.1521
# Epoch 325: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0675 - mse: 0.0675 - mae: 0.1522 - val_loss: 0.0775 - val_mse: 0.0775 - val_mae: 0.1766
# Epoch 326/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1516
# Epoch 326: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1515 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.1740
# Epoch 327/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0675 - mse: 0.0675 - mae: 0.1522
# Epoch 327: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0675 - mse: 0.0675 - mae: 0.1522 - val_loss: 0.0762 - val_mse: 0.0762 - val_mae: 0.1727
# Epoch 328/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1519
# Epoch 328: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1519 - val_loss: 0.0770 - val_mse: 0.0770 - val_mae: 0.1734
# Epoch 329/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1517
# Epoch 329: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1517 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.1725
# Epoch 330/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0675 - mse: 0.0675 - mae: 0.1522
# Epoch 330: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0675 - mse: 0.0675 - mae: 0.1522 - val_loss: 0.0774 - val_mse: 0.0774 - val_mae: 0.1743
# Epoch 331/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0675 - mse: 0.0675 - mae: 0.1521
# Epoch 331: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0675 - mse: 0.0675 - mae: 0.1521 - val_loss: 0.0763 - val_mse: 0.0763 - val_mae: 0.1716
# Epoch 332/3000
# 203/218 [==========================>...] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1513
# Epoch 332: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1513 - val_loss: 0.0765 - val_mse: 0.0765 - val_mae: 0.1732
# Epoch 333/3000
# 205/218 [===========================>..] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1511
# Epoch 333: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1510 - val_loss: 0.0770 - val_mse: 0.0770 - val_mae: 0.1731
# Epoch 334/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1511
# Epoch 334: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1511 - val_loss: 0.0773 - val_mse: 0.0773 - val_mae: 0.1759
# Epoch 335/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1517
# Epoch 335: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1517 - val_loss: 0.0769 - val_mse: 0.0769 - val_mae: 0.1730
# Epoch 336/3000
# 201/218 [==========================>...] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1511
# Epoch 336: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1509 - val_loss: 0.0774 - val_mse: 0.0774 - val_mae: 0.1768
# Epoch 337/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1515
# Epoch 337: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0674 - mse: 0.0674 - mae: 0.1515 - val_loss: 0.0764 - val_mse: 0.0764 - val_mae: 0.1717
# Epoch 338/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1511
# Epoch 338: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1511 - val_loss: 0.0775 - val_mse: 0.0775 - val_mae: 0.1731
# Epoch 339/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1511
# Epoch 339: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1511 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.1731
# Epoch 340/3000
# 205/218 [===========================>..] - ETA: 0s - loss: 0.0671 - mse: 0.0671 - mae: 0.1504
# Epoch 340: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1506 - val_loss: 0.0763 - val_mse: 0.0763 - val_mae: 0.1716
# Epoch 341/3000
# 212/218 [============================>.] - ETA: 0s - loss: 0.0672 - mse: 0.0672 - mae: 0.1509
# Epoch 341: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1512 - val_loss: 0.0762 - val_mse: 0.0762 - val_mae: 0.1728
# Epoch 342/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0674 - mse: 0.0674 - mae: 0.1508
# Epoch 342: val_loss did not improve from 0.07613
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1506 - val_loss: 0.0769 - val_mse: 0.0769 - val_mae: 0.1747
# Epoch 343/3000
# 202/218 [==========================>...] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1507
# Epoch 343: val_loss improved from 0.07613 to 0.07596, saving model to models/first_stage_lstm_weight/epoch_343_0.07596.h5
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1507 - val_loss: 0.0760 - val_mse: 0.0760 - val_mae: 0.1715
# Epoch 344/3000
# 215/218 [============================>.] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1507
# Epoch 344: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1507 - val_loss: 0.0768 - val_mse: 0.0768 - val_mae: 0.1754
# Epoch 345/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0672 - mse: 0.0672 - mae: 0.1505
# Epoch 345: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1505 - val_loss: 0.0767 - val_mse: 0.0767 - val_mae: 0.1744
# Epoch 346/3000
# 218/218 [==============================] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1510
# Epoch 346: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1510 - val_loss: 0.0765 - val_mse: 0.0765 - val_mae: 0.1728
# Epoch 347/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0672 - mse: 0.0672 - mae: 0.1506
# Epoch 347: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1505 - val_loss: 0.0769 - val_mse: 0.0769 - val_mae: 0.1753
# Epoch 348/3000
# 217/218 [============================>.] - ETA: 0s - loss: 0.0671 - mse: 0.0671 - mae: 0.1504
# Epoch 348: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1505 - val_loss: 0.0762 - val_mse: 0.0762 - val_mae: 0.1713
# Epoch 349/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0672 - mse: 0.0672 - mae: 0.1504
# Epoch 349: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1504 - val_loss: 0.0763 - val_mse: 0.0763 - val_mae: 0.1729
# Epoch 350/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0673 - mse: 0.0673 - mae: 0.1509
# Epoch 350: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0673 - mse: 0.0673 - mae: 0.1509 - val_loss: 0.0761 - val_mse: 0.0761 - val_mae: 0.1712
# Epoch 351/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0672 - mse: 0.0672 - mae: 0.1507
# Epoch 351: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 5ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1508 - val_loss: 0.0764 - val_mse: 0.0764 - val_mae: 0.1727
# Epoch 352/3000
# 216/218 [============================>.] - ETA: 0s - loss: 0.0672 - mse: 0.0672 - mae: 0.1504
# Epoch 352: val_loss did not improve from 0.07596
# 218/218 [==============================] - 1s 4ms/step - loss: 0.0672 - mse: 0.0672 - mae: 0.1503 - val_loss: 0.0766 - val_mse: 0.0766 - val_mae: 0.1718
# Epoch 353/3000
# 144/218 [==================>...........] - ETA: 0s - loss: 0.0666 - mse: 0.0666 - mae: 0.1496
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 16>()
#      14 first_stage_lstm_model.summary()
#      15 first_stage_lstm_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae'])
# ---> 16 train_history = first_stage_lstm_model.fit(x=corr_datasets[0], y=corr_datasets[0], validation_data=(corr_datasets[1], corr_datasets[1]), epochs=3000, batch_size=10, shuffle=True, callbacks=callbacks_list, verbose=1)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/training.py:1414, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1412 logs = tmp_logs  # No error, now safe to assign to logs.
#    1413 end_step = step + data_handler.step_increment
# -> 1414 callbacks.on_train_batch_end(end_step, logs)
#    1415 if self.stop_training:
#    1416   break
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     431 """Calls the `on_train_batch_end` methods of its callbacks.
#     432
#     433 Args:
#     434     batch: Integer, index of batch within the current epoch.
#     435     logs: Dict. Aggregated metric results up until this batch.
#     436 """
#     437 if self._should_call_train_batch_hooks:
# --> 438   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     295   self._call_batch_begin_hook(mode, batch, logs)
#     296 elif hook == 'end':
# --> 297   self._call_batch_end_hook(mode, batch, logs)
#     298 else:
#     299   raise ValueError(
#     300       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     315   batch_time = time.time() - self._batch_start_time
#     316   self._batch_times.append(batch_time)
# --> 318 self._call_batch_hook_helper(hook_name, batch, logs)
#     320 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     321   end_hook_name = hook_name
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     354 for callback in self.callbacks:
#     355   hook = getattr(callback, hook_name)
# --> 356   hook(batch, logs)
#     358 if self._check_timing:
#     359   if hook_name not in self._hook_times:
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1033 def on_train_batch_end(self, batch, logs=None):
# -> 1034   self._batch_update_progbar(batch, logs)
#
# File /usr/local/lib/python3.8/dist-packages/keras/callbacks.py:1107, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1104 if self.verbose == 1:
#    1105   # Only block async when verbose = 1.
#    1106   logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1107   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# KeyboardInterrupt:
# time: 5min 45s (started: 2022-09-03 16:59:14 +00:00)

# %%
best_epoch_num = np.argmin(np.array(train_history.history['val_loss'])) + 1
best_val_loss = train_history.history['val_loss'][epoch_num-1]
best_first_stage_lstm_model = load_model(Path(model_dir)/f"epoch_{best_epoch_num}_{best_val_loss:.5f}.h5")
# Out:
# time: 169 ms (started: 2022-09-03 16:28:14 +00:00)

# %%
for (file_name, dataset) in tqdm(zip(['train', 'dev', 'test1', 'test2'], corr_datasets)):
    (dataset, save_file_name=file_name)

# %% [markdown]
# # LSTM for residual

# %%
# Dataset.from_tensor_slices(dict(pd.read_csv(f'./dataset/after_arima/arima_resid_train.csv')))
lstm_train_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_train.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_train_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_train.csv').set_index('Unnamed: 0').iloc[::, -1]
lstm_dev_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_dev.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_dev_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_dev.csv').set_index('Unnamed: 0').iloc[::, -1]
lstm_test1_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test1.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_test1_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test1.csv').set_index('Unnamed: 0').iloc[::, -1]
lstm_test2_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test2.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_test2_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test2.csv').set_index('Unnamed: 0').iloc[::, -1]
num_samples = len(lstm_train_X)

lstm_train_X = lstm_train_X.values.reshape(num_samples, 20, 1)
lstm_train_Y = lstm_train_Y.values.reshape(num_samples, 1)
lstm_dev_X = lstm_dev_X.values.reshape(num_samples, 20, 1)
lstm_dev_Y = lstm_dev_Y.values.reshape(num_samples, 1)
lstm_test1_X = lstm_test1_X.values.reshape(num_samples, 20, 1)
lstm_test1_Y = lstm_test1_Y.values.reshape(num_samples, 1)
lstm_test2_X = lstm_test2_X.values.reshape(num_samples, 20, 1)
lstm_test2_Y = lstm_test2_Y.values.reshape(num_samples, 1)

# %%
def double_tanh(x):
    return (tf.math.tanh(x) *2)


def build_many_one_lstm():
    inputs = Input(shape=(20, 1))
    lstm_1 = LSTM(units=25, kernel_regularizer=l1_l2(0.0, 0.0), bias_regularizer=l1_l2(0.0, 0.0))(inputs)
    outputs = Dense(units=1, activation=double_tanh)(lstm_1)
    return keras.Model(inputs, outputs, name="many_one_lstm")


lstm_model = build_many_one_lstm()
lstm_model.summary()
lstm_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae'])

# %%
model_dir = './models'
log_dir = './models/lstm_train_logs'
res_dir = './results'
os.makedirs(res_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
res_csv_path = Path(res_dir+f'/{output_file_name}_LSTM_evaluation.csv')
res_csv_path.touch(exist_ok=True)
with open(res_csv_path, 'r+') as f:
    if not f.read():
        f.write("epoch,TRAIN_MSE,DEV_MSE,TEST1_MSE,TEST2_MSE,TRAIN_MAE,DEV_MAE,TEST1_MAE,TEST2_MAE")

res_df = pd.read_csv(res_csv_path)
saved_model_list = [int(p.stem.split('_')[1]) for p in Path(model_dir).glob('*.h5')]
model_log = keras.callbacks.TensorBoard(log_dir=log_dir)
epoch_start = max(saved_model_list) if saved_model_list else 1
max_epoch = 3000

for epoch_num in range(epoch_start, max_epoch):
    if epoch_num > 1:
        lstm_model = load_model(Path(model_dir)/f"{output_file_name}_epoch_{epoch_num - 1}.h5", custom_objects={'double_tanh':double_tanh})

    save_model = keras.callbacks.ModelCheckpoint(Path(model_dir)/f"{output_file_name}_epoch_{epoch_num}.h5",
                                                 monitor='loss', verbose=1, mode='min', save_best_only=False)
    lstm_model.fit(lstm_train_X, lstm_train_Y, epochs=1, batch_size=500, shuffle=True, callbacks=[model_log, save_model])
    
    # test the model
    score_train = lstm_model.evaluate(lstm_train_X, lstm_train_Y)
    score_dev = lstm_model.evaluate(lstm_dev_X, lstm_dev_Y)
    score_test1 = lstm_model.evaluate(lstm_test1_X, lstm_test1_Y)
    score_test2 = lstm_model.evaluate(lstm_test2_X, lstm_test2_Y)
    res_each_epoch_df = pd.DataFrame(np.array([epoch_num, score_train[0], score_dev[0], 
                                               score_test1[0], score_test2[0], 
                                               score_train[1], score_dev[1], 
                                               score_test1[1], score_test2[1]]).reshape(-1, 9),
                                    columns=["epoch", "TRAIN_MSE", "DEV_MSE", "TEST1_MSE", 
                                             "TEST2_MSE", "TRAIN_MAE", "DEV_MAE",
                                             "TEST1_MAE","TEST2_MAE"])
    res_df = pd.concat([res_df, res_each_epoch_df])

res_df.to_csv(res_csv_path, index=False)
