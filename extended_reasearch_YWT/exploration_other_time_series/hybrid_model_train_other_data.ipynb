# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import math
import os
from pathlib import Path
import random
from tqdm import tqdm
from itertools import combinations
from sklearn.metrics import mean_squared_error, mean_absolute_error
from pmdarima.arima import ARIMA, auto_arima
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy import stats as st
from sklearn.linear_model import LinearRegression
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l1_l2
from tensorflow.data import Dataset
import warnings
warnings.simplefilter("ignore")

# %load_ext pycodestyle_magic
# %pycodestyle_on --ignore E501
# Out:
# time: 1.88 s (started: 2022-08-31 13:34:05 +00:00)

# %% [markdown]
# # Prepare data

# %%
data_implement = "tetuan_power"  # tw50|sp500|tetuan_power
dataset_path = Path("./dataset/")
if data_implement == "tw50":
    file_name = Path("tw50_hold_20082018_adj_close_pre.csv")
    train_set = ['萬海_adj_close', '豐泰_adj_close', '友達_adj_close', '欣興_adj_close', '台塑化_adj_close', '和泰車_adj_close', '元大金_adj_close', '南電_adj_close', '台塑_adj_close', '統一超_adj_close', '台泥_adj_close', '瑞昱_adj_close', '彰銀_adj_close', '富邦金_adj_close', '研華_adj_close', '中鋼_adj_close', '鴻海_adj_close', '台新金_adj_close', '遠傳_adj_close', '南亞_adj_close', '台達電_adj_close', '台灣大_adj_close', '台化_adj_close', '聯詠_adj_close', '廣達_adj_close', '聯發科_adj_close', '台積電_adj_close', '統一_adj_close', '中信金_adj_close', '長榮_adj_close']
elif data_implement == "sp500":
    file_name = Path("sp500_hold_19972007_adj_close_pre.csv")
    train_set = ['PXD', 'WAT', 'LH', 'AMGN', 'AOS', 'EFX', 'NEM', 'CTAS', 'MAT', 'VLO', 'APH', 'ADM', 'MLM', 'BK', 'NOV', 'BDX', 'RRC', 'IVZ', 'ED', 'SBUX', 'CI', 'ZION', 'COO', 'FDX', 'GLW', 'GPC', 'HPQ', 'ADI', 'AMG', 'MTB', 'YUM', 'SYK', 'KMX', 'AME', 'BMY', 'KMB', 'JPM', 'AET', 'DLTR', 'MGM', 'FL', 'HD', 'CLX', 'OKE', 'WMB', 'IFF', 'CMS', 'MMC', 'REG', 'ES', 'ITW', 'VRTX', 'QCOM', 'MSI', 'NKTR', 'AMAT', 'BWA', 'ESRX', 'TXT', 'VNO', 'WDC', 'PVH', 'NOC', 'PCAR', 'NSC', 'PHM', 'LUV', 'HUM', 'SPG', 'SJM', 'ABT', 'ALK', 'TAP', 'CAT', 'TMO', 'AES', 'MRK', 'RMD', 'MKC', 'HIG', 'DE', 'ATVI', 'O', 'UNM', 'VMC', 'CMA', 'RHI', 'RE', 'FMC', 'MU', 'CB', 'LNT', 'GE', 'SNA', 'LLY', 'LEN', 'MAA', 'OMC', 'F', 'APA', 'CDNS', 'SLG', 'HP', 'SHW', 'AFL', 'STT', 'PAYX', 'AIG']
elif data_implement == "tetuan_power":
    file_name = Path("Tetuan City power consumption_pre.csv")
    train_set = ["Temperature", "Humidity", "Wind Speed", "general diffuse flows", "diffuse flows", "Zone 1 Power Consumption", "Zone 2  Power Consumption", "Zone 3  Power Consumption"]

dataset_df = pd.read_csv(dataset_path/file_name)
all_set = list(dataset_df.columns.values[1:]) # all data
print(f"len(train_set): {len(train_set)}, len(all_set): {len(all_set)}")
      
train_info = {"paper_eva_1": {"items": ['PRGO', 'MRO', 'ADP', 'HCP', 'FITB', 'PEG', 'SYMC', 'EOG', 'MDT', 'NI'], "file_name": "paper_eva_1_res"}, 
              "paper_eva_2": {"items": ['STI', 'COP', 'MCD', 'AON', 'JBHT', 'DISH', 'GS', 'LRCX', 'CTXS', 'LEG'], "file_name": "paper_eva_2_res"},
              "paper_eva_3": {"items": ['TJX', 'EMN', 'JCI', 'C', 'BIIB', 'HOG', 'PX', 'PH', 'XEC', 'JEC'], "file_name": "paper_eva_3_res"},
              "paper_eva_4": {"items": ['ROP', 'AZO', 'URI', 'TROW', 'CMCSA', 'SLB', 'VZ', 'MAC', 'ADS', 'MCK'], "file_name": "paper_eva_4_res"},
              "paper_eva_5": {"items": ['RL', 'CVX', 'SRE', 'PFE', 'PCG', 'UTX', 'NTRS', 'INCY', 'COP', 'HRL'], "file_name": "paper_eva_5_res"},
              "tw50": {"items":train_set, "file_name": "tw50_20082017_res"},
              "sp500": {"items":train_set, "file_name": "sp500_19972007_res"},
              "tetuan_power": {"items": train_set, "file_name":  f"tetuan_power_res"}}
             

items_implement = train_info[data_implement]['items']
output_file_name = train_info[data_implement]['file_name']

dataset_df = dataset_df.set_index('Date')
# display(dataset_df)
# Out:
# len(train_set): 8, len(all_set): 8
# time: 7.05 ms (started: 2022-08-31 13:34:07 +00:00)

# %%
def gen_data_corr(items: list, corr_ind: list) -> "pd.DataFrame":
    tmp_corr = dataset_df[items[0]].rolling(window=100).corr(dataset_df[items[1]])
    tmp_corr = tmp_corr.iloc[corr_ind].values
    data_df = pd.DataFrame(tmp_corr.reshape(-1, 24))
    ind = [f"{items[0]} & {items[1]}_{i}" for i in range(0, 100, 20)]
    data_df.index = ind
    return data_df


def gen_train_data(items: list, corr_ind: list, save_file: bool = False)-> "four pd.DataFrame":
    train_df = pd.DataFrame()
    dev_df = pd.DataFrame()
    test1_df = pd.DataFrame()
    test2_df = pd.DataFrame()

    for pair in tqdm(combinations(items, 2)):
        data_df = gen_data_corr([pair[0], pair[1]], corr_ind=corr_ind)
        data_split = {'train': [0, 21], 'dev': [1, 22], 'test1': [2, 23], 'test2': [3, 24]}
        train_df = pd.concat([train_df, data_df.iloc[:, 0:21]])
        dev_df = pd.concat([dev_df, data_df.iloc[:, 1:22]])
        test1_df = pd.concat([test1_df, data_df.iloc[:, 2:23]])
        test2_df = pd.concat([test2_df, data_df.iloc[:, 3:24]])

    if save_file:
        Path('./dataset/before_arima/').mkdir(parents=True, exist_ok=True)
        train_df.to_csv(f"./dataset/before_arima/{output_file_name}_train.csv")
        dev_df.to_csv(f"./dataset/before_arima/{output_file_name}_dev.csv")
        test1_df.to_csv(f"./dataset/before_arima/{output_file_name}_test1.csv")
        test2_df.to_csv(f"./dataset/before_arima/{output_file_name}_test2.csv")

    return train_df, dev_df, test1_df, test2_df 


corr_ind = list(range(99, 2400, 100))  + list(range(99+20, 2500, 100)) + list(range(99+40, 2500, 100)) + list(range(99+60, 2500, 100)) + list(range(99+80, 2500, 100))
corr_datasets = gen_train_data(items_implement, corr_ind, save_file = True)
# Out:
# 28it [00:00, 637.36it/s]
# time: 57.2 ms (started: 2022-08-31 13:34:07 +00:00)

# %% [markdown]
# # ARIMA model

# %%
def arima_model(dataset: "pd.DataFrame", save_file_name: str = "") -> ("pd.DataFrame", "pd.DataFrame", "pd.DataFrame"):
    model_110 = ARIMA(order=(1, 1, 0), out_of_sample_size=0, mle_regression=True, suppress_warnings=True)
    model_011 = ARIMA(order=(0, 1, 1), out_of_sample_size=0, mle_regression=True, suppress_warnings=True)
    model_111 = ARIMA(order=(1, 1, 1), out_of_sample_size=0, mle_regression=True, suppress_warnings=True)
    model_211 = ARIMA(order=(2, 1, 1), out_of_sample_size=0, mle_regression=True, suppress_warnings=True)
    model_210 = ARIMA(order=(2, 1, 0), out_of_sample_size=0, mle_regression=True, suppress_warnings=True)
    #model_330 = ARIMA(order=(3, 3, 0), out_of_sample_size=0, mle_regression=True, suppress_warnings=True)

    #model_dict = {"model_110": model_110, "model_011": model_011, "model_111": model_111, "model_211": model_211, "model_210": model_210, "model_330": model_330}
    model_dict = {"model_110": model_110, "model_011": model_011, "model_111": model_111, "model_211": model_211, "model_210": model_210}
    tested_models = []
    arima_model = None
    find_arima_model = False
    arima_model_name_list = []
    arima_pred_list = []
    residual = []
    for s in dataset.iterrows():
        while not find_arima_model:
            try:
                for model_key in model_dict:
                    if model_key not in tested_models:
                        test_model = model_dict[model_key].fit(s[1])
                        if arima_model is None:
                            arima_model = test_model
                            arima_model_name = model_key
                        elif arima_model.aic() <= test_model.aic():
                            pass
                        else:
                            arima_model = test_model
                            arima_model_name = model_key
                    tested_models.append(model_key)

            except Exception:
                if len(model_dict)-1 != 0:
                    del model_dict[model_key]
                else:
                    print(f"fatal error, {s[1].name} doesn't have appropriate arima model")
                    break
            else:
                #model_dict = {"model_110": model_110, "model_011": model_011, "model_111": model_111, "model_211": model_211, "model_210": model_210, "model_330": model_330}
                model_dict = {"model_110": model_110, "model_011": model_011, "model_111": model_111, "model_211": model_211, "model_210": model_210}
                tested_models.clear()
                find_arima_model = True

        arima_pred = list(arima_model.predict_in_sample())
        arima_pred = [np.mean(arima_pred[1:])] + arima_pred[1:]
        arima_pred = np.clip(np.array(arima_pred), -1, 1)

        res = pd.Series(np.array(s[1]) - arima_pred)
        arima_model_name_list.append(arima_model_name)
        arima_pred_list.append(arima_pred)
        residual.append(np.array(res))
        find_arima_model = False
    arima_model_name_df = pd.DataFrame(arima_model_name_list)
    arima_pred_df = pd.DataFrame(arima_pred_list)
    arima_resid_df = pd.DataFrame(residual)
    arima_model_name_df.index = dataset.index
    arima_pred_df.index = dataset.index
    arima_resid_df.index = dataset.index

    if save_file_name:
        Path('./dataset/after_arima').mkdir(parents=True, exist_ok=True)
        arima_model_name_df.to_csv(f'./dataset/after_arima/{output_file_name}_arima_model_{save_file_name}.csv')
        arima_pred_df.to_csv(f'./dataset/after_arima/{output_file_name}_arima_pred_{save_file_name}.csv')
        arima_resid_df.to_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_{save_file_name}.csv')

    return arima_model_name_df, arima_pred_df, arima_resid_df
# Out:
# time: 1.89 ms (started: 2022-08-31 13:34:07 +00:00)

# %%
for (file_name, dataset) in tqdm(zip(['train', 'dev', 'test1', 'test2'], corr_datasets)):
    arima_model(dataset, save_file_name=file_name)
# Out:
# 4it [01:38, 24.70s/it]
# time: 1min 38s (started: 2022-08-31 13:34:07 +00:00)

# %% [markdown]
# # LSTM

# %%
# Dataset.from_tensor_slices(dict(pd.read_csv(f'./dataset/after_arima/arima_resid_train.csv')))
lstm_train_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_train.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_train_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_train.csv').set_index('Unnamed: 0').iloc[::, -1]
lstm_dev_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_dev.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_dev_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_dev.csv').set_index('Unnamed: 0').iloc[::, -1]
lstm_test1_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test1.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_test1_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test1.csv').set_index('Unnamed: 0').iloc[::, -1]
lstm_test2_X = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test2.csv').set_index('Unnamed: 0').iloc[::, :-1]
lstm_test2_Y = pd.read_csv(f'./dataset/after_arima/{output_file_name}_arima_resid_test2.csv').set_index('Unnamed: 0').iloc[::, -1]
num_samples = len(lstm_train_X)

lstm_train_X = lstm_train_X.values.reshape(num_samples, 20, 1)
lstm_train_Y = lstm_train_Y.values.reshape(num_samples, 1)
lstm_dev_X = lstm_dev_X.values.reshape(num_samples, 20, 1)
lstm_dev_Y = lstm_dev_Y.values.reshape(num_samples, 1)
lstm_test1_X = lstm_test1_X.values.reshape(num_samples, 20, 1)
lstm_test1_Y = lstm_test1_Y.values.reshape(num_samples, 1)
lstm_test2_X = lstm_test2_X.values.reshape(num_samples, 20, 1)
lstm_test2_Y = lstm_test2_Y.values.reshape(num_samples, 1)
# Out:
# time: 14.7 ms (started: 2022-08-31 13:35:46 +00:00)

# %%
def double_tanh(x):
    return (tf.math.tanh(x) *2)


def build_many_one_lstm():
    inputs = Input(shape=(20, 1))
    lstm_1 = LSTM(units=25, kernel_regularizer=l1_l2(0.0, 0.0), bias_regularizer=l1_l2(0.0, 0.0))(inputs)
    outputs = Dense(units=1, activation=double_tanh)(lstm_1)
    return keras.Model(inputs, outputs, name="many_one_lstm")


lstm_model = build_many_one_lstm()
lstm_model.summary()
lstm_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse', 'mae'])
# Out:
# 2022-08-31 13:35:47.024736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.029137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.029335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.030224: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-31 13:35:47.031432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.031625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.031805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.345089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.345255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.345384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-31 13:35:47.345485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22308 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0b:00.0, compute capability: 8.6
# Model: "many_one_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 1)]           0
#
#  lstm (LSTM)                 (None, 25)                2700
#
#  dense (Dense)               (None, 1)                 26
#
# =================================================================
# Total params: 2,726
# Trainable params: 2,726
# Non-trainable params: 0
# _________________________________________________________________
# time: 1.38 s (started: 2022-08-31 13:35:46 +00:00)

# %%
model_dir = './models'
log_dir = './models/lstm_train_logs'
res_dir = './results'
os.makedirs(res_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
res_csv_path = Path(res_dir+f'/{output_file_name}_LSTM_evaluation.csv')
res_csv_path.touch(exist_ok=True)
with open(res_csv_path, 'r+') as f:
    if not f.read():
        f.write("epoch,TRAIN_MSE,DEV_MSE,TEST1_MSE,TEST2_MSE,TRAIN_MAE,DEV_MAE,TEST1_MAE,TEST2_MAE")

res_df = pd.read_csv(res_csv_path)
saved_model_list = [int(p.stem.split('_')[1]) for p in Path(model_dir).glob('*.h5')]
model_cbk = keras.callbacks.TensorBoard(log_dir=log_dir)
epoch_start = max(saved_model_list) if saved_model_list else 1
max_epoch = 3000

for epoch_num in range(epoch_start, max_epoch):
    if epoch_num > 1:
        lstm_model = load_model(Path(model_dir)/f"{output_file_name}_epoch_{epoch_num - 1}.h5", custom_objects={'double_tanh':double_tanh})

    save_model = keras.callbacks.ModelCheckpoint(Path(model_dir)/f"{output_file_name}_epoch_{epoch_num}.h5",
                                                 monitor='loss', verbose=1, mode='min', save_best_only=False)
    lstm_model.fit(lstm_train_X, lstm_train_Y, epochs=1, batch_size=500, shuffle=True, callbacks=[model_cbk, save_model])
    
    # test the model
    score_train = lstm_model.evaluate(lstm_train_X, lstm_train_Y)
    score_dev = lstm_model.evaluate(lstm_dev_X, lstm_dev_Y)
    score_test1 = lstm_model.evaluate(lstm_test1_X, lstm_test1_Y)
    score_test2 = lstm_model.evaluate(lstm_test2_X, lstm_test2_Y)
    res_each_epoch_df = pd.DataFrame(np.array([epoch_num, score_train[0], score_dev[0], 
                                               score_test1[0], score_test2[0], 
                                               score_train[1], score_dev[1], 
                                               score_test1[1], score_test2[1]]).reshape(-1, 9),
                                    columns=["epoch", "TRAIN_MSE", "DEV_MSE", "TEST1_MSE", 
                                             "TEST2_MSE", "TRAIN_MAE", "DEV_MAE",
                                             "TEST1_MAE","TEST2_MAE"])
    res_df = pd.concat([res_df, res_each_epoch_df])

res_df.to_csv(res_csv_path, index=False)
# Out:
# 2022-08-31 13:35:48.917726: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 1/1 [==============================] - ETA: 0s - loss: 0.0115 - mse: 0.0115 - mae: 0.0825
# Epoch 1: saving model to models/tetuan_power_res_epoch_1.h5
# 1/1 [==============================] - 2s 2s/step - loss: 0.0115 - mse: 0.0115 - mae: 0.0825
# 2022-08-31 13:35:49.346753: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0819
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0175 - mse: 0.0175 - mae: 0.1050
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0098 - mse: 0.0098 - mae: 0.0698
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0715
# 1/1 [==============================] - ETA: 0s - loss: 0.0110 - mse: 0.0110 - mae: 0.0819
# Epoch 1: saving model to models/tetuan_power_res_epoch_2.h5
# 1/1 [==============================] - 1s 527ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0819
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0822
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0178 - mse: 0.0178 - mae: 0.1082
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0727
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0759
# 1/1 [==============================] - ETA: 0s - loss: 0.0109 - mse: 0.0109 - mae: 0.0822
# Epoch 1: saving model to models/tetuan_power_res_epoch_3.h5
# 1/1 [==============================] - 1s 683ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0822
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0828
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0181 - mse: 0.0181 - mae: 0.1103
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0751
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0794
# 1/1 [==============================] - ETA: 0s - loss: 0.0109 - mse: 0.0109 - mae: 0.0828
# Epoch 1: saving model to models/tetuan_power_res_epoch_4.h5
# 1/1 [==============================] - 1s 518ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0828
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0826
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0181 - mse: 0.0181 - mae: 0.1105
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0756
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0801
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x7f2c8048b430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s - loss: 0.0109 - mse: 0.0109 - mae: 0.0826
# Epoch 1: saving model to models/tetuan_power_res_epoch_5.h5
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0826
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0820
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0178 - mse: 0.0178 - mae: 0.1092
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0744
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0786
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x7f2c802e7700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - ETA: 0s - loss: 0.0107 - mse: 0.0107 - mae: 0.0820
# Epoch 1: saving model to models/tetuan_power_res_epoch_6.h5
# 1/1 [==============================] - 1s 531ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0820
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0811
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0174 - mse: 0.0174 - mae: 0.1072
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0725
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0760
# 1/1 [==============================] - ETA: 0s - loss: 0.0105 - mse: 0.0105 - mae: 0.0811
# Epoch 1: saving model to models/tetuan_power_res_epoch_7.h5
# 1/1 [==============================] - 1s 531ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0811
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0802
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0170 - mse: 0.0170 - mae: 0.1049
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0096 - mse: 0.0096 - mae: 0.0704
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.
- ETA: 0s - loss: 0.0088 - mse: 0.0088 - mae: 0.0733
# Epoch 1: saving model to models/tetuan_power_res_epoch_21.h5
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0733
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0725
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0144 - mse: 0.0144 - mae: 0.0957
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0635
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0650
# 1/1 [==============================] - ETA: 0s - loss: 0.0087 - mse: 0.0087 - mae: 0.0725
# Epoch 1: saving model to models/tetuan_power_res_epoch_22.h5
# 1/1 [==============================] - 1s 749ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0725
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0718
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0142 - mse: 0.0142 - mae: 0.0952
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0631
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0646
# 1/1 [==============================] - ETA: 0s - loss: 0.0085 - mse: 0.0085 - mae: 0.0718
# Epoch 1: saving model to models/tetuan_power_res_epoch_23.h5
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0718
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0713
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0141 - mse: 0.0141 - mae: 0.0952
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0633
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0652
# 1/1 [==============================] - ETA: 0s - loss: 0.0083 - mse: 0.0083 - mae: 0.0713
# Epoch 1: saving model to models/tetuan_power_res_epoch_24.h5
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0713
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0709
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0141 - mse: 0.0141 - mae: 0.0957
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0639
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0664
# 1/1 [==============================] - ETA: 0s - loss: 0.0081 - mse: 0.0081 - mae: 0.0709
# Epoch 1: saving model to models/tetuan_power_res_epoch_25.h5
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0709
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0705
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0140 - mse: 0.0140 - mae: 0.0961
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0646
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0675
# 1/1 [==============================] - ETA: 0s - loss: 0.0080 - mse: 0.0080 - mae: 0.0705
# Epoch 1: saving model to models/tetuan_power_res_epoch_26.h5
# 1/1 [==============================] - 1s 509ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0705
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0697
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0139 - mse: 0.0139 - mae: 0.0957
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0645
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0674
# 1/1 [==============================] - ETA: 0s - loss: 0.0078 - mse: 0.0078 - mae: 0.0697
# Epoch 1: saving model to models/tetuan_power_res_epoch_27.h5
# 1/1 [==============================] - 1s 734ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0697
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0686
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0136 - mse: 0.0136 - mae: 0.0943
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0634
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0657
# 1/1 [==============================] - ETA: 0s - loss: 0.0076 - mse: 0.0076 - mae: 0.0686
# Epoch 1: saving model to models/tetuan_power_res_epoch_28.h5
# 1/1 [==============================] - 1s 512ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0686
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0673
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0924
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0618
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0630
# 1/1 [==============================] - ETA: 0s - loss: 0.0074 - mse: 0.0074 - mae: 0.0673
# Epoch 1: saving model to models/tetuan_power_res_epoch_29.h5
# 1/1 [==============================] - 1s 512ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0673
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0662
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0129 - mse: 0.0129 - mae: 0.0907
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0605
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0608
# 1/1 [==============================] - ETA: 0s - loss: 0.0072 - mse: 0.0072 - mae: 0.0662
# Epoch 1: saving model to models/tetuan_power_res_epoch_30.h5
# 1/1 [==============================] - 1s 513ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0662
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0654
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0127 - mse: 0.0127 - mae: 0.0899
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0603
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0601
# 1/1 [==============================] - ETA: 0s - loss: 0.0070 - mse: 0.0070 - mae: 0.0654
# Epoch 1: saving model to models/tetuan_power_res_epoch_31.h5
# 1/1 [==============================] - 1s 710ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0654
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0647
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0126 - mse: 0.0126 - mae: 0.0903
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0612
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0610
# 1/1 [==============================] - ETA: 0s - loss: 0.0068 - mse: 0.0068 - mae: 0.0647
# Epoch 1: saving model to models/tetuan_power_res_epoch_32.h5
# 1/1 [==============================] - 1s 513ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0647
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0642
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0126 - mse: 0.0126 - mae: 0.0910
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0626
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0623
# 1/1 [==============================] - ETA: 0s - loss: 0.0067 - mse: 0.0067 - mae: 0.0642
# Epoch 1: saving model to models/tetuan_power_res_epoch_33.h5
# 1/1 [==============================] - 1s 525ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0642
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0635
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0125 - mse: 0.0125 - mae: 0.0905
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0626
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0617
# 1/1 [==============================] - ETA: 0s - loss: 0.0065 - mse: 0.0065 - mae: 0.0635
# Epoch 1: saving model to models/tetuan_power_res_epoch_34.h5
# 1/1 [==============================] - 1s 516ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0635
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0624
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0121 - mse: 0.0121 - mae: 0.0884
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0612
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0589
# 1/1 [==============================] - ETA: 0s - loss: 0.0063 - mse: 0.0063 - mae: 0.0624
# Epoch 1: saving model to models/tetuan_power_res_epoch_35.h5
# 1/1 [==============================] - 1s 513ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0624
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0614
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0118 - mse: 0.0118 - mae: 0.0864
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0601
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0561
# 1/1 [==============================] - ETA: 0s - loss: 0.0062 - mse: 0.0062 - mae: 0.0614
# Epoch 1: saving model to models/tetuan_power_res_epoch_36.h5
# 1/1 [==============================] - 1s 754ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0614
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0609
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0118 - mse: 0.0118 - mae: 0.0862
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0607
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0562
# 1/1 [==============================] - ETA: 0s - loss: 0.0061 - mse: 0.0061 - mae: 0.0609
# Epoch 1: saving model to models/tetuan_power_res_epoch_37.h5
# 1/1 [==============================] - 1s 523ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0609
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0611
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0874
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0625
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0580
# 1/1 [==============================] - ETA: 0s - loss: 0.0060 - mse: 0.0060 - mae: 0.0611
# Epoch 1: saving model to models/tetuan_power_res_epoch_38.h5
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0611
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0608
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0118 - mse: 0.0118 - mae: 0.0868
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0627
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0575
# 1/1 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0608
# Epoch 1: saving model to models/tetuan_power_res_epoch_39.h5
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0608
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0597
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0114 - mse: 0.0114 - mae: 0.0842
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0609
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0545
# 1/1 [==============================] - ETA: 0s - loss: 0.0059 - mse: 0.0059 - mae: 0.0597
# Epoch 1: saving model to models/tetuan_power_res_epoch_40.h5
# 1/1 [==============================] - 1s 712ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0597
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0590
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0828
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0602
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0531
# 1/1 [==============================] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0590
# Epoch 1: saving model to models/tetuan_power_res_epoch_41.h5
# 1/1 [==============================] - 1s 522ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0590
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0591
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0836
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0612
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0547
# 1/1 [==============================] - ETA: 0s - loss: 0.0057 - mse: 0.0057 - mae: 0.0591
# Epoch 1: saving model to models/tetuan_power_res_epoch_42.h5
# 1/1 [==============================] - 1s 524ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0591
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0588
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0835
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0614
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0553
# 1/1 [==============================] - ETA: 0s - loss: 0.0056 - mse: 0.0056 - mae: 0.0588
# Epoch 1: saving model to models/tetuan_power_res_epoch_43.h5
# 1/1 [==============================] - 1s 522ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0588
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0575
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0106 - mse: 0.0106 - mae: 0.0811
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0595
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0530
# 1/1 [==============================] - ETA: 0s - loss: 0.0054 - mse: 0.0054 - mae: 0.0575
# Epoch 1: saving model to models/tetuan_power_res_epoch_44.h5
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0575
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0564
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0793
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0581
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0515
# 1/1 [==============================] - ETA: 0s - loss: 0.0053 - mse: 0.0053 - mae: 0.0564
# Epoch 1: saving model to models/tetuan_power_res_epoch_45.h5
# 1/1 [==============================] - 1s 747ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0564
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0560
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0795
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0584
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0527
# 1/1 [==============================] - ETA: 0s - loss: 0.0052 - mse: 0.0052 - mae: 0.0560
# Epoch 1: saving model to models/tetuan_power_res_epoch_46.h5
# 1/1 [==============================] - 1s 517ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0560
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0557
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0794
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0585
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0537
# 1/1 [==============================] - ETA: 0s - loss: 0.0050 - mse: 0.0050 - mae: 0.0557
# Epoch 1: saving model to models/tetuan_power_res_epoch_47.h5
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0557
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0546
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0776
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0569
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0522
# 1/1 [==============================] - ETA: 0s - loss: 0.0049 - mse: 0.0049 - mae: 0.0546
# Epoch 1: saving model to models/tetuan_power_res_epoch_48.h5
# 1/1 [==============================] - 1s 523ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0546
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0535
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0759
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0552
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0507
# 1/1 [==============================] - ETA: 0s - loss: 0.0048 - mse: 0.0048 - mae: 0.0535
# Epoch 1: saving model to models/tetuan_power_res_epoch_49.h5
# 1/1 [==============================] - 1s 718ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0535
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0532
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0755
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0551
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0512
# 1/1 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0532
# Epoch 1: saving model to models/tetuan_power_res_epoch_50.h5
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0532
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0533
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0754
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0553
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0522
# 1/1 [==============================] - ETA: 0s - loss: 0.0047 - mse: 0.0047 - mae: 0.0533
# Epoch 1: saving model to models/tetuan_power_res_epoch_51.h5
# 1/1 [==============================] - 1s 533ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0533
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0527
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0743
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0544
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0515
# 1/1 [==============================] - ETA: 0s - loss: 0.0046 - mse: 0.0046 - mae: 0.0527
# Epoch 1: saving model to models/tetuan_power_res_epoch_52.h5
# 1/1 [==============================] - 1s 525ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0527
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0519
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0728
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0529
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0499
# 1/1 [==============================] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0519
# Epoch 1: saving model to models/tetuan_power_res_epoch_53.h5
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0519
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0515
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0720
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0526
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0498
# 1/1 [==============================] - ETA: 0s - loss: 0.0045 - mse: 0.0045 - mae: 0.0515
# Epoch 1: saving model to models/tetuan_power_res_epoch_54.h5
# 1/1 [==============================] - 1s 757ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0515
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0514
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0718
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0531
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0506
# 1/1 [==============================] - ETA: 0s - loss: 0.0044 - mse: 0.0044 - mae: 0.0514
# Epoch 1: saving model to models/tetuan_power_res_epoch_55.h5
# 1/1 [==============================] - 1s 514ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0514
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0509
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0709
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0527
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0502
# 1/1 [==============================] - ETA: 0s - loss: 0.0043 - mse: 0.0043 - mae: 0.0509
# Epoch 1: saving model to models/tetuan_power_res_epoch_56.h5
# 1/1 [==============================] - 1s 523ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0509
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0500
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0694
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0517
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# 1/1 [==============================] - ETA: 0s - loss: 0.0042 - mse: 0.0042 - mae: 0.0500
# Epoch 1: saving model to models/tetuan_power_res_epoch_57.h5
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0500
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0497
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0688
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0516
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0485
# 1/1 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0497
# Epoch 1: saving model to models/tetuan_power_res_epoch_58.h5
# 1/1 [==============================] - 1s 738ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0497
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0497
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0688
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0524
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0493
# 1/1 [==============================] - ETA: 0s - loss: 0.0041 - mse: 0.0041 - mae: 0.0497
# Epoch 1: saving model to models/tetuan_power_res_epoch_59.h5
# 1/1 [==============================] - 1s 526ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0497
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0492
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0678
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0519
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0484
# 1/1 [==============================] - ETA: 0s - loss: 0.0040 - mse: 0.0040 - mae: 0.0492
# Epoch 1: saving model to models/tetuan_power_res_epoch_60.h5
# 1/1 [==============================] - 1s 531ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0492
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0667
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0515
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0473
# 1/1 [==============================] - ETA: 0s - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# Epoch 1: saving model to models/tetuan_power_res_epoch_61.h5
# 1/1 [==============================] - 1s 531ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0671
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0524
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0483
# 1/1 [==============================] - ETA: 0s - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# Epoch 1: saving model to models/tetuan_power_res_epoch_62.h5
# 1/1 [==============================] - 1s 525ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0487
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0482
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0663
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0521
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0478
# 1/1 [==============================] - ETA: 0s - loss: 0.0039 - mse: 0.0039 - mae: 0.0482
# Epoch 1: saving model to models/tetuan_power_res_epoch_63.h5
# 1/1 [==============================] - 1s 761ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0482
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0477
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0651
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0514
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0469
# 1/1 [==============================] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0477
# Epoch 1: saving model to models/tetuan_power_res_epoch_64.h5
# 1/1 [==============================] - 1s 517ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0477
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0478
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0656
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0519
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0482
# 1/1 [==============================] - ETA: 0s - loss: 0.0038 - mse: 0.0038 - mae: 0.0478
# Epoch 1: saving model to models/tetuan_power_res_epoch_65.h5
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0478
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0472
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0643
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0508
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0474
# 1/1 [==============================] - ETA: 0s - loss: 0.0037 - mse: 0.0037 - mae: 0.0472
# Epoch 1: saving model to models/tetuan_power_res_epoch_66.h5
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0472
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0469
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0636
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0502
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0474
# 1/1 [==============================] - ETA: 0s - loss: 0.0037 